# %% [markdown]
# ### TASK
# *   Convert the payroll report into a tabular form with one header row.
# *   Send back the output table(s) created and any scripts/code/Excel workbooks
#
# ### MY APPROACH
# 1. Explored CSV file to get rough idea about the given data and its structure, and to think about how I convert the report into a tabular form with one header row.
# 2. Checked column data uniqueness to get detail information about the given data and to identify what data I could clean.
# 3. Removed unnecessary columns.
# 4. Splitted given CSV into smaller dataframes and put it to the easier structure.
#
# *   First dictionary: {emp_id, emp_salary_details}
# *   Second dictionary: {emp_id, emp_salary_totals}
# *   Third dictionary: {company total and average, respective amounts}
#
#   *Please note that dictionary values were in dataframe structure.*
#
# 5. Removed unnecessary rows.
# 6. Removed unnecessary columns.
# 7. Filled empty dates in emp_salary_details dataframe using ffill() function to make next step (reshaping dataframe) easier.
# 8. Reshaped dataframes using unstack() function to make dataframe with a one header.
# 9. Concatenated all dataframes to the one big dataframe.
# 10. Exported resulted dataframe into CSV.
#
# ### IDENTIFIED ISSUES
# 1. Missing values <br>
# 1 week (between 1983/08/22 and 1983/09/05) was missing for 009KENTG	Garry Kent salary details.
# 1 week (between 1982/07/19 and 1982/08/02) was missing for 021MOODL Luann Moody salary details
# 2. 1983/08/22 and 1983/09/05 salary details were identical for 009KENTG	Garry Kent salary details.
# 3. Suspicious description:
# <br> ZZZFirst Aid -hourly retail award (don't us <br>
# e)
#
#
# ### CODE SCRIPT WITH BRIEF DESCRIPTION
#
# *Please note that you need to rename given data as payroll_raw_data.csv and upload it to the content folder in google colab to run the code.*
#
# **THE FIRST 3 STEPS APPLIED AS FOLLOWS:**
# 1. Explored CSV file to get rough idea about the given data and its structure, and to think about how I convert the report into a tabular form with one header row.
# 2. Checked column data uniqueness to get detail information about the given data and to identify what data I could clean.
# 3. Removed unnecessary columns.

# %%
import pandas as pd

# %%
# import given raw data
raw_data = pd.read_csv('/content/payroll_raw_data.csv', header=None)
print('Raw data shape: ', raw_data.shape)
raw_data.head(10)
# Out:
# Raw data shape:  (30550, 12)
#                                                   0                1   \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                         Employee Previous Earnings              NaN
# 3                                    Payroll Company              NaN
# 4                                           001POWED  Dominick Powers
# 5  For Pay End Periods between 1/07/1982 and 25/0...              NaN
# 6                                                NaN              NaN
# 7                                    Period End Date    Pay Frequency
# 8                                         1982/12/06    1W01 - Weekly
# 9                                                NaN              NaN
#
#                                                   2         3          4   \
# 0                                                NaN       NaN        NaN
# 1                                                NaN       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3  AMALGAMATED WIDGETS - AMALGAMATED WIDGETS PTY LTD       NaN        NaN
# 4                                                NaN       NaN        NaN
# 5                                                NaN       NaN        NaN
# 6                                                NaN       NaN  Number of
# 7                                                NaN  Location        NaN
# 8                                                NaN   CARCOSA          1
# 9                                                NaN       NaN        NaN
#
#                             5   6   7   8    9      10             11
# 0   Employee Previous Earnings NaN NaN NaN  NaN    NaN            NaN
# 1  AMALGAMATED WIDGETS PTY LTD NaN NaN NaN  NaN    NaN            NaN
# 2                          NaN NaN NaN NaN  NaN    NaN  Page 1 of 553
# 3                          NaN NaN NaN NaN  NaN    NaN            NaN
# 4                          NaN NaN NaN NaN  NaN    NaN            NaN
# 5                          NaN NaN NaN NaN  NaN    NaN            NaN
# 6                          NaN NaN NaN NaN  NaN    NaN            NaN
# 7                  Description NaN NaN NaN  NaN  Hours         Amount
# 8                          NaN NaN NaN NaN  NaN    NaN            NaN
# 9                 Normal Hours NaN NaN NaN  NaN     23         351.87

# %% [markdown]
# From above result, we can see that the given file has 30550 rows and 12 columns and it includes employees' weekly salary information. <br> In order to understand the data throughly, let's have a look uniqueness of data column by column.

# %%
print(raw_data[raw_data.columns[0]].unique())
# Out:
# [nan 'Employee Previous Earnings' 'Payroll Company' '001POWED'
#  'For Pay End Periods between 1/07/1982 and 25/06/1985' 'Period End Date'
#  '1982/12/06' '1982/12/13' '1982/12/20' '1982/12/27' '1983/01/03'
#  '1983/01/10' '1983/01/17' '1983/01/24'
#  'ACME Payroll (Registered to AMALGAMATED CO. PTY. LTD.)' '1983/01/31'
#  '1983/02/07' '1983/02/14' '1983/02/21' '1983/02/28' '1983/03/07'
#  '1983/03/14' '1983/03/21' '1983/03/28' '1983/04/04' '1983/04/11'
#  '1983/04/18' '1983/04/25' '1983/05/02' '1983/05/09' '1983/05/16'
#  '1983/05/23' '1983/05/30' 'Employee Total' '002MORIC' '1985/04/16'
#  '1985/04/23' '1985/04/30' '1985/05/07' '003DALTE' '1982/07/05'
#  '1982/07/12' '1982/07/19' '1982/07/26' '1982/08/02' '1982/08/09'
#  '1982/08/16' '1982/08/23' '1982/08/30' '1982/09/06' '1982/09/13'
#  '1982/09/20' '1982/09/27' '1982/10/04' '1982/10/11' '1982/10/18'
#  '1982/10/25' '1982/11/01' '1982/11/08' '1982/11/15' '1982/11/22'
#  '1982/11/29' '1983/06/06' '1983/06/13' '1983/06/20' '1983/06/27'
#  '1983/07/04' '1983/07/11' '1983/07/18' '1983/07/25' '004NASHK'
#  '1983/08/01' '1983/08/08' '1983/08/15' '1983/08/22' '1983/08/29'
#  '1983/09/05' '1983/09/12' '1983/09/19' '1983/09/26' '1983/10/03'
#  '1983/10/10' '1983/10/17' '1983/10/24' '1983/10/31' '1983/11/07'
#  '1983/11/14' '1983/11/21' '1983/11/28' '1983/12/05' '1983/12/12'
#  '1983/12/19' '1983/12/26' '1984/01/02' '1984/01/09' '1984/01/16'
#  '1984/01/23' '1984/01/30' '1984/02/06' '1984/02/13' '1984/02/20'
#  '1984/02/27' '1984/03/06' '1984/03/13' '1984/03/20' '1984/03/27'
#  '1984/04/03' '1984/04/10' '1984/04/17' '1984/04/24' '1984/05/01'
#  '1984/05/08' '1984/05/15' '1984/05/22' '1984/05/29' '1984/06/05'
#  '1984/06/12' '1984/06/19' '1984/06/26' '1984/07/03' '1984/07/10'
#  '1984/07/17' '1984/07/24' '1984/07/31' '1984/08/07' '1984/08/14'
#  '1984/08/21' '1984/08/28' '1984/09/04' '1984/09/11' '1984/09/18'
#  '1984/09/25' '1984/10/02' '1984/10/09' '1984/10/16' '1984/10/23'
#  '1984/10/30' '1984/11/06' '1984/11/13' '1984/11/20' '1984/11/27'
#  '1984/12/04' '1984/12/11' '1984/12/18' '1984/12/25' '1985/01/01'
#  '1985/01/08' '1985/01/15' '1985/01/22' '1985/01/29' '1985/02/05'
#  '1985/02/12' '1985/02/19' '1985/02/26' '1985/03/05' '1985/03/12'
#  '1985/03/19' '1985/03/26' '1985/04/02' '1985/04/09' '1985/05/14'
#  '1985/05/21' '1985/05/28' '1985/06/04' '1985/06/11' '1985/06/18'
#  '1985/06/25' '005RANDH' '006BROWA' '007GAINA' '008CALHR' '009KENTG'
#  '010GOLDM' '011MCCOJ' '012GAMBM' '013DIXOM' '014ELLIS' '015RUSHP'
#  '016LUCAB' '017SIMSN' '018DELAL' '019MCINC' '020LYONM' '021MOODL'
#  '022TORRH' '023ALFOV' '024DELGI' '025PACEI' '026ELLIG' '027BRYAC'
#  '028MILES' '029BALLS' '030CONWR' '031MONTC' '032BEARC' '033TODDR'
#  '034WILLS' '035RODRE' '036DEANM' '037WALLB' '038CARNE' '039CARSL'
#  '040MENDL' '041KERRE' '042GEORC' '043LUCAA' '044FIGUC' '045WESTB'
#  '046MCGOL' '047BAILT' '048LOWEP' 'Payroll Company Total' 'Average']

# %% [markdown]
# In column 0, important information are **period end dates** and **employee ids**. Also, we could notice that there are employee total and company total and average data in the given file because those labels are in this column. In addition, we could judge this file includes 48 employees' 3 years salary data due to given date interval **between 1/07/1982 and 25/06/1985** and the last employee id **048LOWEP**.

# %%
print(raw_data[raw_data.columns[1]].unique())
# Out:
# [nan 'Dominick Powers' 'Pay Frequency' '1W01 - Weekly' 'Crystal Morin'
#  'Erma Dalton' 'Kristy Nash' 'Henrietta Randall' 'Avis Browning'
#  'Abigail Gaines' 'Randell Calhoun' 'Garry Kent' 'Melanie Golden'
#  'Jonathan Mcconnell' 'Merrill Gamble' 'Mauro Dixon' 'Sara Ellis'
#  'Phil Rush' 'Beth Lucas' 'Nola Sims' 'Larry Delaney' 'Christy Mcintyre'
#  'Milo Lyons' 'Luann Moody' 'Hans Torres' 'Velma Alford' 'Imogene Delgado'
#  'Irving Pace' 'Georgina Ellison' 'Corinne Bryant' 'Stefan Miles'
#  'Simon Ball' 'Rosanna Conway' 'Charley Montgomery' 'Cathy Beard'
#  'Ryan Todd' 'Sammy Williamson' 'Eunice Rodriguez' 'Mercedes Dean'
#  'Brandie Wall' 'Ethel Carney' 'Leonel Carson' 'Luz Mendez' 'Etta Kerr'
#  'Claudio George' 'Anibal Lucas' 'Charlie Figueroa' 'Bertha West'
#  'Leanne Mcgowan' 'Tamara Bailey' 'Patty Lowe']

# %% [markdown]
# In column 1, important information is **employee names**. Also, we could see payment frequency is weekly from the above information.

# %%
print(raw_data[raw_data.columns[2]].unique())
# Out:
# [nan 'AMALGAMATED WIDGETS - AMALGAMATED WIDGETS PTY LTD']

# %%
print(raw_data[raw_data.columns[3]].unique())
# Out:
# [nan 'Location' 'CARCOSA']

# %%
print(raw_data[raw_data.columns[4]].unique())
# Out:
# [nan 'Number of' '1' '2' '5']

# %% [markdown]
# In column 2, we can see company name. <br>
# In column 3, we can see that location is CARCOSA. <br>
# In column 4, we could see number of something.

# %%
print(raw_data[raw_data.columns[5]].unique())
# Out:
# ['Employee Previous Earnings' 'AMALGAMATED WIDGETS PTY LTD' nan
#  'Description' 'Normal Hours' 'Gross Taxable Total' 'Tax (Incl Adjust)'
#  'Net Pay' 'Superannuation' 'Public Holiday - worked' 'Time/Half Hours'
#  'Reimburse expenses' 'Uniforms - Reducing Balance' 'Sat Casual Ldg'
#  'Other Leave - Public Holiday' 'Annual Leave' 'Sick Leave'
#  'Other Leave - Birthday' 'Term AL Gross' 'Account Payment'
#  '60% Sun Perm Ldg' 'Leave Loading 17.5%' 'Sunday Ldg'
#  'Other Leave - Unpaid Leave- No accruals' 'Long Service Leave'
#  'Term LL Gross' 'ETP - Taxable (Post June 83) Code : O' '   Gratuity'
#  'Sat Perm Loading' 'Term LSL Gross' 'Sun Cas Ldg'
#  'Other Leave - Jury Duty' 'Jury Duty Subsidy'
#  'Reimburse expenses- Flu Vax' 'Other Leave - Bereavement'
#  'Other Leave - Leave w/out pay- with accr' 'uals'
#  'SUPER SUPER VOL CONT $' "ZZZFirst Aid -hourly retail award (don't us"
#  'e)' 'First Aid- Retail award - wkly' 'First Aid - Retail Hourly Rate'
#  'Re-imburse expense - Safety Boots'
#  'Other Leave - Sick Leave - No accrual' 'Over Award' '   Tax Adjustment'
#  'Key Allowance' 'Loan Repayments - Reducing balance'
#  'Salary Sacrifice - YSI Life' 'Salary Sacrifice - Super Superannuation'
#  'Other Leave - Workcover- lve accrued' 'Bonus'
#  'Salary Sacrifice - Carcosan Super' 'Other Leave - Compassionate'
#  'Other Leave - Paternity Leave- 1 wk paid']

# %% [markdown]
# In column 5, we can see salary **pay description** basically, which is important to keep.

# %%
print(raw_data[raw_data.columns[6]].unique())
# Out:
# [nan]

# %%
print(raw_data[raw_data.columns[7]].unique())
# Out:
# [nan]

# %%
print(raw_data[raw_data.columns[8]].unique())
# Out:
# [nan]

# %%
print(raw_data[raw_data.columns[9]].unique())
# Out:
# [nan '2022/06/30 00:00:00.653']

# %% [markdown]
# We can say that column 6, column 7, column 8 and column 9 are unnecessary as 3 of them are empty and one of them has only 1 unique value.

# %%
print(raw_data[raw_data.columns[10]].unique())
# Out:
# [nan 'Hours' '23' '0' '46' '37.5' '30' '15' '32' '5.5' '31' '37' '33.5'
#  '35.5' '35.25' '34.5' '33.25' '41.5' '16.5' '8.5' '41.75' '25' '34'
#  '14.5' '852' '23.5' '19.5' '4' '99.5' '40' '8' '10' '32.5' '7.5' '28'
#  '12' '196.83' '2170' '29.5' '56.5' '16' '28.5' '29' '21' '25.5' '3' '4.5'
#  '14' '7' '27.5' '20.5' '6.5' '27.25' '29.25' '26.5' '21.5' '28.75' '3.5'
#  '17' '26' '5' '22.25' '6.25' '1.25' '2' '22.5' '6' '34.25' '3771.25'
#  '63.25' '377' '65.5' '50' '693.75' '102.5' '307.5' '38' '76' '18' '20'
#  '61' '36.25' '1.75' '37.25' '0.75' '25.75' '12.25' '38.5' '17.75' '20.25'
#  '60.47' '190' '621' '58' '66' '342' '43' '40.5' '33' '9.25' '92.5' '12.5'
#  '11' '11.5' '27' '17.5' '1' '18.75' '3.75' '24.5' '795' '104' '75'
#  '109.5' '146.25' '35' '24' '15.5' '15.25' '6.94' '264.08' '720.5' '43.5'
#  '117' '19' '9.5' '9' '29.75' '22' '8.25' '10.5' '36.5' '41' '39' '35.75'
#  '45' '36.75' '2443.25' '72.5' '288' '244.5' '31.5' '32.25' '13.5' '13'
#  '3466.25' '71.5' '267' '39.5' '138' '1.5' '32.75' '33.75' '-17.5' '2.5'
#  '18.5' '4.75' '12.75' '3457.75' '124.5' '363' '53' '51.75' '23.25'
#  '24.25' '42.5' '11.25' '14.25' '-7.5' '46.5' '34.75' '6.75' '36' '2565.5'
#  '126.5' '273' '699.25' '42' '30.5' '40.25' '-3' '38.75' '3.25' '0.5'
#  '45.25' '31.25' '39.25' '18.25' '21.75' '21.25' '8.75' '4.25' '5128.25'
#  '44.25' '89.25' '490.5' '64.5' '105.25' '229.5' '48' '4726.5' '134.5'
#  '238.5' '63' '936.5' '365.5' '17.25' '65.56' '14.75' '7.25' '25.25'
#  '10.75' '1891.25' '102.56' '229.75' '256.75' '22.75' '480.75' '201'
#  '26.21' '808.75' '71' '80' '98' '62' '89.04' '899.75' '274.5' '234.25'
#  '230' '82.5' '48.75' '47' '150' '5048.5' '157.5' '450.5' '52' '86.5'
#  '564' '142.5' '366.25' '1.85' '23.75' '44.5' '4102.75' '96.5' '477' '311'
#  '340.5' '133.5' '30.25' '30.75' '28.25' '2.75' '4112' '106.25' '349.5'
#  '193' '19.25' '16.25' '-7.75' '25.9' '283.49' '1346' '149.5' '487' '68'
#  '17.88' '1.38' '1017' '86.38' '122.5' '74.75' '54.25' '332' '106' '13.25'
#  '56' '926.5' '238' '242' '16.75' '1246' '448.5' '840' '51.5' '160.75'
#  '5.25' '37.75' '38.25' '26.25' '5.75' '198.83' '417.34' '3958' '59.25'
#  '135.5' '359' '178.75' '170.5' '7.15' '100.5' '0.25' '364.75' '70.5'
#  '46.25' '16.42' '206' '10.25' '52.5' '47.5' '217.5' '5003.75' '101.75'
#  '124.25' '388' '44' '120' '653.5' '68.5' '315.5' '147' '402' '79' '65'
#  '1.3' '4269.25' '181.3' '422.5' '107' '1970.5' '48.5' '54' '395' '15.75'
#  '21.02' '807.75' '31.75' '41.25' '42.75' '70.75' '2646.5' '90' '158'
#  '5627.5' '493' '-8' '160' '5215.5' '540' '334.5' '280' '173.5' '5293.5'
#  '266.5' '447' '200.5' '173.71' '2032.5' '199.5' '92486.75' '343.75'
#  '2520.3' '6569.09' '639' '265' '1598.5' '767.75' '3593.5' '1335.25'
#  '1621.75' '1733.25' '2540.25' '1440.25' '889.35' '964.9099999999999'
#  '26.447454961395483' '0.0982985416070918' '0.7207034601086646'
#  '1.8784929939948527' '0.18272805261652844' '0.01372605090077209'
#  '0.07577923934801258' '0.002573634543894767' '0.02973977695167286'
#  '0.03009722619388047' '0.01143837575064341' '0.4571060909350872'
#  '0.02030311695739205' '0.21954532456391193' '0.012582213325707749'
#  '1.0275950814984272' '0.26780097226193883' '0.38182728052616527'
#  '0.4637546468401487' '0.4956391192450672' '0.7264083500142979'
#  '0.41185301687160425' '0.25431798684586787' '0.27592507863883325']

# %%
print(raw_data[raw_data.columns[11]].unique())
# Out:
# [nan 'Page 1 of 553' 'Amount' ... '-0.1789104947097512'
#  '636.7198341435585' '68.33625107234788']

# %% [markdown]
# Column 10 includes hours while column 11 includes amount.

# %% [markdown]
# **After observed uniqueness of data column by column, we could summarize as folows:**
#
# **Columns to keep:**<br>
# Column 0 - Pay end dates and employee ids <br>
# Column 1 - Employee names <br>
# Column 5 - Descriptions <br>
# Column 10 - Hours <br>
# Column 11 - Amount <br>
#
# **Columns to remove:**<br>
# Column 2 has only one unique value ([nan 'AMALGAMATED WIDGETS - AMALGAMATED WIDGETS PTY LTD']). <br>
# Column 3 has only one unique value ([nan 'Location' 'CARCOSA']). <br>
# Column 4 has 4 unique values ([nan 'Number of' '1' '2' '5']) but it is not quite relevant to the rest data.  <br>
# Column 6 - Empty<br>
# Column 7 - Empty<br>
# Column 8 - Empty<br>
# Column 9 has only one unique value ([nan '2022/06/30 00:00:00.653']) <br>
#
# Although we remove some columns, we should be aware of some data in it for the future. So that, let's keep them here.<br>
#
# Payroll company: **AMALGAMATED WIDGETS - AMALGAMATED WIDGETS PTY LTD** <br>
# Location: **CARCOSA**

# %%
#remove columns by indexing
raw_data = raw_data.drop(raw_data.columns[[2, 3, 4, 6, 7, 8, 9]], axis=1)

# %%
print("Raw data shape after removed unnecessary columns: ", raw_data.shape)
raw_data.head(20)
# Out:
# Raw data shape after removed unnecessary columns:  (30550, 5)
#                                                    0                1   \
# 0                                                 NaN              NaN
# 1                                                 NaN              NaN
# 2                          Employee Previous Earnings              NaN
# 3                                     Payroll Company              NaN
# 4                                            001POWED  Dominick Powers
# 5   For Pay End Periods between 1/07/1982 and 25/0...              NaN
# 6                                                 NaN              NaN
# 7                                     Period End Date    Pay Frequency
# 8                                          1982/12/06    1W01 - Weekly
# 9                                                 NaN              NaN
# 10                                                NaN              NaN
# 11                                                NaN              NaN
# 12                                                NaN              NaN
# 13                                         1982/12/13    1W01 - Weekly
# 14                                                NaN              NaN
# 15                                                NaN              NaN
# 16                                                NaN              NaN
# 17                                                NaN              NaN
# 18                                                NaN              NaN
# 19                                         1982/12/20    1W01 - Weekly
#
#                              5      10             11
# 0    Employee Previous Earnings    NaN            NaN
# 1   AMALGAMATED WIDGETS PTY LTD    NaN            NaN
# 2                           NaN    NaN  Page 1 of 553
# 3                           NaN    NaN            NaN
# 4                           NaN    NaN            NaN
# 5                           NaN    NaN            NaN
# 6                           NaN    NaN            NaN
# 7                   Description  Hours         Amount
# 8                           NaN    NaN            NaN
# 9                  Normal Hours     23         351.87
# 10          Gross Taxable Total      0         351.87
# 11            Tax (Incl Adjust)      0             -0
# 12                      Net Pay      0         351.87
# 13                          NaN    NaN            NaN
# 14                 Normal Hours     46         703.74
# 15          Gross Taxable Total      0         703.74
# 16            Tax (Incl Adjust)      0            -80
# 17                      Net Pay      0         623.74
# 18               Superannuation      0          66.86
# 19                          NaN    NaN            NaN

# %% [markdown]
# We could see there are some unnecessary rows but let's keep those rows at this stage to avoid indices confusion for splitting a big dataframe. We will remove unnecessary rows in later stages.

# %% [markdown]
# **THE 4TH STEP APPLIED AS FOLLOWS:**
# 4. Splitted given CSV into smaller dataframes and put it to the easier structure.
#
# *   First dictionary: {emp_id, emp_salary_details}
# *   Second dictionary: {emp_id, emp_salary_totals}
# *   Third dictionary: {company total and average, respective amounts}
#
#   *Please note that dictionary values were in dataframe structure.*

# %% [markdown]
# Collected all employees ids from the unique output of column 0 to use them as keys in dictionary structure:
#
#
# '001POWED' '002MORIC' '003DALTE' '004NASHK''005RANDH' '006BROWA' '007GAINA' '008CALHR' '009KENTG' '010GOLDM' '011MCCOJ' '012GAMBM' '013DIXOM' '014ELLIS' '015RUSHP' '016LUCAB' '017SIMSN' '018DELAL' '019MCINC' '020LYONM' '021MOODL' '022TORRH' '023ALFOV' '024DELGI' '025PACEI' '026ELLIG' '027BRYAC' '028MILES' '029BALLS' '030CONWR' '031MONTC' '032BEARC' '033TODDR' '034WILLS' '035RODRE' '036DEANM' '037WALLB' '038CARNE' '039CARSL' '040MENDL' '041KERRE' '042GEORC' '043LUCAA' '044FIGUC' '045WESTB' '046MCGOL' '047BAILT' '048LOWEP'

# %%
# list of employee ids
list_emp_ids = ['001POWED', '002MORIC', '003DALTE', '004NASHK', '005RANDH', '006BROWA', '007GAINA', '008CALHR', '009KENTG', '010GOLDM', '011MCCOJ', '012GAMBM', '013DIXOM', '014ELLIS', '015RUSHP', '016LUCAB', '017SIMSN', '018DELAL', '019MCINC', '020LYONM', '021MOODL', '022TORRH', '023ALFOV', '024DELGI', '025PACEI', '026ELLIG', '027BRYAC', '028MILES', '029BALLS', '030CONWR', '031MONTC', '032BEARC', '033TODDR', '034WILLS', '035RODRE', '036DEANM', '037WALLB', '038CARNE', '039CARSL', '040MENDL', '041KERRE', '042GEORC', '043LUCAA', '044FIGUC', '045WESTB', '046MCGOL', '047BAILT', '048LOWEP']
# list to keep indices which we can use for splitting CSV by each employee.
list_indices = []
# dictionary to keep employee ids as keys and employee names as values.
dic_emp_names = {}

for id in list_emp_ids:
  index = raw_data[raw_data.iloc[:,0] == id].index[0]
  list_indices.append(index-4)
  dic_emp_names[id] = raw_data.loc[index, 1]

list_index_by_emp = list(zip(list_emp_ids, list_indices))

print("List of indices:\n", list_indices)
print("List of indices with respective employee ids:\n", list_index_by_emp)
print("Dictionary of employee names:\n", dic_emp_names.items())
# Out:
# List of indices:
#  [0, 207, 247, 680, 2087, 2123, 2349, 2778, 3055, 3784, 4869, 6070, 7078, 8329, 9908, 10750, 11005, 11393, 11420, 11921, 12035, 13426, 13456, 14787, 16232, 16899, 16985, 17356, 17445, 17597, 17759, 18188, 18771, 19203, 20478, 20583, 20719, 20798, 22467, 22554, 22729, 24301, 24847, 25258, 26084, 27442, 28800, 30006]
# List of indices with respective employee ids:
#  [('001POWED', 0), ('002MORIC', 207), ('003DALTE', 247), ('004NASHK', 680), ('005RANDH', 2087), ('006BROWA', 2123), ('007GAINA', 2349), ('008CALHR', 2778), ('009KENTG', 3055), ('010GOLDM', 3784), ('011MCCOJ', 4869), ('012GAMBM', 6070), ('013DIXOM', 7078), ('014ELLIS', 8329), ('015RUSHP', 9908), ('016LUCAB', 10750), ('017SIMSN', 11005), ('018DELAL', 11393), ('019MCINC', 11420), ('020LYONM', 11921), ('021MOODL', 12035), ('022TORRH', 13426), ('023ALFOV', 13456), ('024DELGI', 14787), ('025PACEI', 16232), ('026ELLIG', 16899), ('027BRYAC', 16985), ('028MILES', 17356), ('029BALLS', 17445), ('030CONWR', 17597), ('031MONTC', 17759), ('032BEARC', 18188), ('033TODDR', 18771), ('034WILLS', 19203), ('035RODRE', 20478), ('036DEANM', 20583), ('037WALLB', 20719), ('038CARNE', 20798), ('039CARSL', 22467), ('040MENDL', 22554), ('041KERRE', 22729), ('042GEORC', 24301), ('043LUCAA', 24847), ('044FIGUC', 25258), ('045WESTB', 26084), ('046MCGOL', 27442), ('047BAILT', 28800), ('048LOWEP', 30006)]
# Dictionary of employee names:
#  dict_items([('001POWED', 'Dominick Powers'), ('002MORIC', 'Crystal Morin'), ('003DALTE', 'Erma Dalton'), ('004NASHK', 'Kristy Nash'), ('005RANDH', 'Henrietta Randall'), ('006BROWA', 'Avis Browning'), ('007GAINA', 'Abigail Gaines'), ('008CALHR', 'Randell Calhoun'), ('009KENTG', 'Garry Kent'), ('010GOLDM', 'Melanie Golden'), ('011MCCOJ', 'Jonathan Mcconnell'), ('012GAMBM', 'Merrill Gamble'), ('013DIXOM', 'Mauro Dixon'), ('014ELLIS', 'Sara Ellis'), ('015RUSHP', 'Phil Rush'), ('016LUCAB', 'Beth Lucas'), ('017SIMSN', 'Nola Sims'), ('018DELAL', 'Larry Delaney'), ('019MCINC', 'Christy Mcintyre'), ('020LYONM', 'Milo Lyons'), ('021MOODL', 'Luann Moody'), ('022TORRH', 'Hans Torres'), ('023ALFOV', 'Velma Alford'), ('024DELGI', 'Imogene Delgado'), ('025PACEI', 'Irving Pace'), ('026ELLIG', 'Georgina Ellison'), ('027BRYAC', 'Corinne Bryant'), ('028MILES', 'Stefan Miles'), ('029BALLS', 'Simon Ball'), ('030CONWR', 'Rosanna Conway'), ('031MONTC', 'Charley Montgomery'), ('032BEARC', 'Cathy Beard'), ('033TODDR', 'Ryan Todd'), ('034WILLS', 'Sammy Williamson'), ('035RODRE', 'Eunice Rodriguez'), ('036DEANM', 'Mercedes Dean'), ('037WALLB', 'Brandie Wall'), ('038CARNE', 'Ethel Carney'), ('039CARSL', 'Leonel Carson'), ('040MENDL', 'Luz Mendez'), ('041KERRE', 'Etta Kerr'), ('042GEORC', 'Claudio George'), ('043LUCAA', 'Anibal Lucas'), ('044FIGUC', 'Charlie Figueroa'), ('045WESTB', 'Bertha West'), ('046MCGOL', 'Leanne Mcgowan'), ('047BAILT', 'Tamara Bailey'), ('048LOWEP', 'Patty Lowe')])

# %%
# creating dictionary with employee ids as keys and salary details dataframe as values
start_index = 0
key_emp_id = ''
dic_emp_salary = {}

for emp_id, index in list_index_by_emp:
  if index == 0:
    key_emp_id = emp_id
    continue

  dic_emp_salary[key_emp_id] = raw_data.iloc[start_index:index,:]

  start_index = index
  key_emp_id = emp_id

dic_emp_salary[key_emp_id] = raw_data.iloc[start_index:,:]

print("The last employee ID: " + key_emp_id)
# Out:
# The last employee ID: 048LOWEP

# %%
print("The 1st employee dataframe shape: ", dic_emp_salary['001POWED'].shape)
print("The 2nd employee dataframe shape: ", dic_emp_salary['002MORIC'].shape)
print("The 3rd employee dataframe shape: ", dic_emp_salary['003DALTE'].shape)
print("The 20th employee dataframe shape: ", dic_emp_salary['020LYONM'].shape)
print("The 21st employee dataframe shape: ", dic_emp_salary['021MOODL'].shape)
print("The 47th employee dataframe shape: ", dic_emp_salary['047BAILT'].shape)
print("The 48th employee dataframe shape: ", dic_emp_salary['048LOWEP'].shape)
# Out:
# The 1st employee dataframe shape:  (207, 5)
# The 2nd employee dataframe shape:  (40, 5)
# The 3rd employee dataframe shape:  (433, 5)
# The 20th employee dataframe shape:  (114, 5)
# The 21st employee dataframe shape:  (1391, 5)
# The 47th employee dataframe shape:  (1206, 5)
# The 48th employee dataframe shape:  (544, 5)

# %% [markdown]
# After quick look at raw data file, we can confirm the shape of dataframes for above employees are correct. However, the last employee's dataframe includes company total and company average data, so that we should take care of that in the next steps.
#
# Let's have a look some employees dataframes below.

# %%
dic_emp_salary['001POWED']
# Out:
#                                                     0                1   \
# 0                                                  NaN              NaN
# 1                                                  NaN              NaN
# 2                           Employee Previous Earnings              NaN
# 3                                      Payroll Company              NaN
# 4                                             001POWED  Dominick Powers
# ..                                                 ...              ...
# 202                                                NaN              NaN
# 203                                                NaN              NaN
# 204                                                NaN              NaN
# 205                                                NaN              NaN
# 206  ACME Payroll (Registered to AMALGAMATED CO. PT...              NaN
#
#                               5    10             11
# 0     Employee Previous Earnings  NaN            NaN
# 1    AMALGAMATED WIDGETS PTY LTD  NaN            NaN
# 2                            NaN  NaN  Page 1 of 553
# 3                            NaN  NaN            NaN
# 4                            NaN  NaN            NaN
# ..                           ...  ...            ...
# 202           Reimburse expenses    0             50
# 203  Uniforms - Reducing Balance    0            -33
# 204                      Net Pay    0       13438.16
# 205               Superannuation    0        1363.42
# 206                          NaN  NaN            NaN
#
# [207 rows x 5 columns]

# %%
dic_emp_salary['002MORIC']
# Out:
#                                                     0              1   \
# 207                                                NaN            NaN
# 208                                                NaN            NaN
# 209                         Employee Previous Earnings            NaN
# 210                                    Payroll Company            NaN
# 211                                           002MORIC  Crystal Morin
# 212  For Pay End Periods between 1/07/1982 and 25/0...            NaN
# 213                                                NaN            NaN
# 214                                    Period End Date  Pay Frequency
# 215                                         1985/04/16  1W01 - Weekly
# 216                                                NaN            NaN
# 217                                                NaN            NaN
# 218                                                NaN            NaN
# 219                                                NaN            NaN
# 220                                                NaN            NaN
# 221                                         1985/04/23  1W01 - Weekly
# 222                                                NaN            NaN
# 223                                                NaN            NaN
# 224                                                NaN            NaN
# 225                                                NaN            NaN
# 226                                                NaN            NaN
# 227                                         1985/04/30  1W01 - Weekly
# 228                                                NaN            NaN
# 229                                                NaN            NaN
# 230                                                NaN            NaN
# 231                                                NaN            NaN
# 232                                                NaN            NaN
# 233                                                NaN            NaN
# 234                                         1985/05/07  1W01 - Weekly
# 235                                                NaN            NaN
# 236                                                NaN            NaN
# 237                                                NaN            NaN
# 238                                                NaN            NaN
# 239                                     Employee Total            NaN
# 240                                                NaN            NaN
# 241                                                NaN            NaN
# 242                                                NaN            NaN
# 243                                                NaN            NaN
# 244                                                NaN            NaN
# 245                                                NaN            NaN
# 246  ACME Payroll (Registered to AMALGAMATED CO. PT...            NaN
#
#                               5      10                  11
# 207   Employee Previous Earnings    NaN                 NaN
# 208  AMALGAMATED WIDGETS PTY LTD    NaN                 NaN
# 209                          NaN    NaN       Page 5 of 553
# 210                          NaN    NaN                 NaN
# 211                          NaN    NaN                 NaN
# 212                          NaN    NaN                 NaN
# 213                          NaN    NaN                 NaN
# 214                  Description  Hours              Amount
# 215                          NaN    NaN                 NaN
# 216                 Normal Hours     46             1003.22
# 217          Gross Taxable Total      0             1003.22
# 218            Tax (Incl Adjust)      0                 -85
# 219                      Net Pay      0              918.22
# 220               Superannuation      0   95.30000000000001
# 221                          NaN    NaN                 NaN
# 222                 Normal Hours   19.5              425.27
# 223          Gross Taxable Total      0              425.27
# 224            Tax (Incl Adjust)      0                 -14
# 225                      Net Pay      0              411.27
# 226               Superannuation      0                40.4
# 227                          NaN    NaN                 NaN
# 228                 Normal Hours     30              654.27
# 229               Sat Casual Ldg    8.5               14.83
# 230          Gross Taxable Total      0               669.1
# 231            Tax (Incl Adjust)      0                 -73
# 232                      Net Pay      0               596.1
# 233               Superannuation      0               63.56
# 234                          NaN    NaN                 NaN
# 235                 Normal Hours      4               87.24
# 236          Gross Taxable Total      0               87.24
# 237            Tax (Incl Adjust)      0                  -0
# 238                      Net Pay      0               87.24
# 239                          NaN    NaN                 NaN
# 240                 Normal Hours   99.5                2170
# 241               Sat Casual Ldg    8.5               14.83
# 242          Gross Taxable Total      0             2184.83
# 243            Tax (Incl Adjust)      0                -172
# 244                      Net Pay      0  2012.8300000000002
# 245               Superannuation      0  199.26000000000002
# 246                          NaN    NaN                 NaN

# %%
dic_emp_salary['048LOWEP']
# Out:
#                                                       0           1   \
# 30006                                                NaN         NaN
# 30007                                                NaN         NaN
# 30008                         Employee Previous Earnings         NaN
# 30009                                    Payroll Company         NaN
# 30010                                           048LOWEP  Patty Lowe
# ...                                                  ...         ...
# 30545                                                NaN         NaN
# 30546                                                NaN         NaN
# 30547                                                NaN         NaN
# 30548                                                NaN         NaN
# 30549  ACME Payroll (Registered to AMALGAMATED CO. PT...         NaN
#
#                                 5    10                   11
# 30006   Employee Previous Earnings  NaN                  NaN
# 30007  AMALGAMATED WIDGETS PTY LTD  NaN                  NaN
# 30008                          NaN  NaN      Page 544 of 553
# 30009                          NaN  NaN                  NaN
# 30010                          NaN  NaN                  NaN
# ...                            ...  ...                  ...
# 30545       SUPER SUPER VOL CONT $    0   -1.043751787246211
# 30546  Uniforms - Reducing Balance    0  -0.1789104947097512
# 30547                      Net Pay    0    636.7198341435585
# 30548               Superannuation    0    68.33625107234788
# 30549                          NaN  NaN                  NaN
#
# [544 rows x 5 columns]

# %% [markdown]
# In order to ease reshaping dataframe, it is better to save "employees total" and "companies total and average" data separatedly from employee salary description data.

# %%
# creating dictionary with employee ids as keys and totals dataframe as values
dic_emp_total = {}

for emp_id, index in list_index_by_emp:
  df_emp = dic_emp_salary[emp_id]
  emp_total_index = df_emp[df_emp.loc[:,0] == 'Employee Total'].index[0]

  dic_emp_salary[emp_id] = df_emp.loc[:emp_total_index-1,:]
  dic_emp_total[emp_id] = df_emp.loc[emp_total_index:,:]

# %% [markdown]
# Let's see our results below for employee with the ID of "002MORIC".

# %%
dic_emp_salary['002MORIC']
# Out:
#                                                     0              1   \
# 207                                                NaN            NaN
# 208                                                NaN            NaN
# 209                         Employee Previous Earnings            NaN
# 210                                    Payroll Company            NaN
# 211                                           002MORIC  Crystal Morin
# 212  For Pay End Periods between 1/07/1982 and 25/0...            NaN
# 213                                                NaN            NaN
# 214                                    Period End Date  Pay Frequency
# 215                                         1985/04/16  1W01 - Weekly
# 216                                                NaN            NaN
# 217                                                NaN            NaN
# 218                                                NaN            NaN
# 219                                                NaN            NaN
# 220                                                NaN            NaN
# 221                                         1985/04/23  1W01 - Weekly
# 222                                                NaN            NaN
# 223                                                NaN            NaN
# 224                                                NaN            NaN
# 225                                                NaN            NaN
# 226                                                NaN            NaN
# 227                                         1985/04/30  1W01 - Weekly
# 228                                                NaN            NaN
# 229                                                NaN            NaN
# 230                                                NaN            NaN
# 231                                                NaN            NaN
# 232                                                NaN            NaN
# 233                                                NaN            NaN
# 234                                         1985/05/07  1W01 - Weekly
# 235                                                NaN            NaN
# 236                                                NaN            NaN
# 237                                                NaN            NaN
# 238                                                NaN            NaN
#
#                               5      10                 11
# 207   Employee Previous Earnings    NaN                NaN
# 208  AMALGAMATED WIDGETS PTY LTD    NaN                NaN
# 209                          NaN    NaN      Page 5 of 553
# 210                          NaN    NaN                NaN
# 211                          NaN    NaN                NaN
# 212                          NaN    NaN                NaN
# 213                          NaN    NaN                NaN
# 214                  Description  Hours             Amount
# 215                          NaN    NaN                NaN
# 216                 Normal Hours     46            1003.22
# 217          Gross Taxable Total      0            1003.22
# 218            Tax (Incl Adjust)      0                -85
# 219                      Net Pay      0             918.22
# 220               Superannuation      0  95.30000000000001
# 221                          NaN    NaN                NaN
# 222                 Normal Hours   19.5             425.27
# 223          Gross Taxable Total      0             425.27
# 224            Tax (Incl Adjust)      0                -14
# 225                      Net Pay      0             411.27
# 226               Superannuation      0               40.4
# 227                          NaN    NaN                NaN
# 228                 Normal Hours     30             654.27
# 229               Sat Casual Ldg    8.5              14.83
# 230          Gross Taxable Total      0              669.1
# 231            Tax (Incl Adjust)      0                -73
# 232                      Net Pay      0              596.1
# 233               Superannuation      0              63.56
# 234                          NaN    NaN                NaN
# 235                 Normal Hours      4              87.24
# 236          Gross Taxable Total      0              87.24
# 237            Tax (Incl Adjust)      0                 -0
# 238                      Net Pay      0              87.24

# %%
dic_emp_total['002MORIC']
# Out:
#                                                     0    1   \
# 239                                     Employee Total  NaN
# 240                                                NaN  NaN
# 241                                                NaN  NaN
# 242                                                NaN  NaN
# 243                                                NaN  NaN
# 244                                                NaN  NaN
# 245                                                NaN  NaN
# 246  ACME Payroll (Registered to AMALGAMATED CO. PT...  NaN
#
#                       5     10                  11
# 239                  NaN   NaN                 NaN
# 240         Normal Hours  99.5                2170
# 241       Sat Casual Ldg   8.5               14.83
# 242  Gross Taxable Total     0             2184.83
# 243    Tax (Incl Adjust)     0                -172
# 244              Net Pay     0  2012.8300000000002
# 245       Superannuation     0  199.26000000000002
# 246                  NaN   NaN                 NaN

# %% [markdown]
# Now, let's split company total and company average data from the last employee's total data.

# %%
# creating dictionary with "company_total" and "company_avg" as keys and respective values in dataframe as values
dic_company = {}

df_last_emp_total = dic_emp_total['048LOWEP']
company_total_index = df_last_emp_total[df_last_emp_total.loc[:,0] == 'Payroll Company Total'].index[0]
company_avg_index = df_last_emp_total[df_last_emp_total.loc[:,0] == 'Average'].index[0]

dic_company['company_total'] = df_last_emp_total.loc[company_total_index+1:company_avg_index-1,:]
dic_company['company_avg'] = df_last_emp_total.loc[company_avg_index+1:,:]
dic_emp_total['048LOWEP'] = df_last_emp_total.loc[:company_total_index-1,:]

# %% [markdown]
# Results of company total and company average below.

# %%
dic_company['company_total']
# Out:
#                                                       0    1   \
# 30443                                                NaN  NaN
# 30444                                                NaN  NaN
# 30445                                                NaN  NaN
# 30446                                                NaN  NaN
# 30447                                                NaN  NaN
# 30448                                                NaN  NaN
# 30449                                                NaN  NaN
# 30450                                                NaN  NaN
# 30451                                                NaN  NaN
# 30452                                                NaN  NaN
# 30453                                                NaN  NaN
# 30454                                                NaN  NaN
# 30455                                                NaN  NaN
# 30456                                                NaN  NaN
# 30457                                                NaN  NaN
# 30458                                                NaN  NaN
# 30459                                                NaN  NaN
# 30460                                                NaN  NaN
# 30461                                                NaN  NaN
# 30462                                                NaN  NaN
# 30463                                                NaN  NaN
# 30464                                                NaN  NaN
# 30465                                                NaN  NaN
# 30466                                                NaN  NaN
# 30467                                                NaN  NaN
# 30468                                                NaN  NaN
# 30469                                                NaN  NaN
# 30470                                                NaN  NaN
# 30471                                                NaN  NaN
# 30472                                                NaN  NaN
# 30473                                                NaN  NaN
# 30474                                                NaN  NaN
# 30475                                                NaN  NaN
# 30476                                                NaN  NaN
# 30477                                                NaN  NaN
# 30478                                                NaN  NaN
# 30479                                                NaN  NaN
# 30480                                                NaN  NaN
# 30481                                                NaN  NaN
# 30482                                                NaN  NaN
# 30483                                                NaN  NaN
# 30484                                                NaN  NaN
# 30485                                                NaN  NaN
# 30486                                                NaN  NaN
# 30487                                                NaN  NaN
# 30488                                                NaN  NaN
# 30489                                                NaN  NaN
# 30490                                                NaN  NaN
# 30491                                                NaN  NaN
# 30492                                                NaN  NaN
# 30493  ACME Payroll (Registered to AMALGAMATED CO. PT...  NaN
# 30494                                                NaN  NaN
# 30495                                                NaN  NaN
# 30496                         Employee Previous Earnings  NaN
# 30497                                    Payroll Company  NaN
#
#                                                 5                  10  \
# 30443                                 Normal Hours           92486.75
# 30444                              Time/Half Hours             343.75
# 30445                                   Sick Leave             2520.3
# 30446                                 Annual Leave            6569.09
# 30447                           Long Service Leave                639
# 30448                    Other Leave - Bereavement                 48
# 30449                       Other Leave - Birthday                265
# 30450                  Other Leave - Compassionate                  9
# 30451                      Other Leave - Jury Duty                104
# 30452     Other Leave - Leave w/out pay- with accr             105.25
# 30453                                         uals                NaN
# 30454     Other Leave - Paternity Leave- 1 wk paid                 40
# 30455                 Other Leave - Public Holiday             1598.5
# 30456        Other Leave - Sick Leave - No accrual                 71
# 30457      Other Leave - Unpaid Leave- No accruals             767.75
# 30458         Other Leave - Workcover- lve accrued                 44
# 30459                             60% Sun Perm Ldg             3593.5
# 30460                                        Bonus                  0
# 30461               First Aid - Retail Hourly Rate              936.5
# 30462               First Aid- Retail award - wkly                  0
# 30463                                Key Allowance                  0
# 30464                          Leave Loading 17.5%                  0
# 30465                                   Over Award                  0
# 30466                      Public Holiday - worked            1335.25
# 30467                               Sat Casual Ldg            1621.75
# 30468                             Sat Perm Loading            1733.25
# 30469                                  Sun Cas Ldg            2540.25
# 30470                                   Sunday Ldg            1440.25
# 30471  ZZZFirst Aid -hourly retail award (don't us                  0
# 30472                                           e)                NaN
# 30473                  Salary Sacrifice - YSI Life                  0
# 30474            Salary Sacrifice - Carcosan Super                  0
# 30475      Salary Sacrifice - Super Superannuation                  0
# 30476                                Term AL Gross             889.35
# 30477                                Term LL Gross                  0
# 30478                               Term LSL Gross  964.9099999999999
# 30479        ETP - Taxable (Post June 83) Code : O                  0
# 30480                          Gross Taxable Total                  0
# 30481                            Tax (Incl Adjust)                  0
# 30482                               Tax Adjustment                  0
# 30483            Re-imburse expense - Safety Boots                  0
# 30484                           Reimburse expenses                  0
# 30485                  Reimburse expenses- Flu Vax                  0
# 30486                              Account Payment                  0
# 30487                            Jury Duty Subsidy                  0
# 30488           Loan Repayments - Reducing balance                  0
# 30489                       SUPER SUPER VOL CONT $                  0
# 30490                  Uniforms - Reducing Balance                  0
# 30491                                      Net Pay                  0
# 30492                               Superannuation                  0
# 30493                                          NaN                NaN
# 30494                   Employee Previous Earnings                NaN
# 30495                  AMALGAMATED WIDGETS PTY LTD                NaN
# 30496                                          NaN                NaN
# 30497                                          NaN                NaN
#
#                        11
# 30443  2102742.6800000034
# 30444  10633.759999999998
# 30445   61061.16000000009
# 30446  152592.36000000013
# 30447            14692.64
# 30448  1004.0799999999999
# 30449   6260.930000000001
# 30450              367.79
# 30451             2237.06
# 30452                   0
# 30453                 NaN
# 30454             1365.39
# 30455  39035.969999999965
# 30456                   0
# 30457                   0
# 30458              994.23
# 30459  43910.590000000004
# 30460                6450
# 30461   271.7600000000001
# 30462  2372.6900000000032
# 30463                7392
# 30464  17444.020000000008
# 30465                3525
# 30466   63136.97000000004
# 30467  3065.8699999999985
# 30468    9453.92000000002
# 30469  36138.630000000034
# 30470   24999.45999999993
# 30471  1174.7600000000004
# 30472                 NaN
# 30473               -8550
# 30474               -2350
# 30475               -4525
# 30476            21142.75
# 30477  1933.6599999999999
# 30478            20462.04
# 30479   7109.389999999999
# 30480  2647546.5600000694
# 30481             -413164
# 30482               -1694
# 30483                 200
# 30484             1034.98
# 30485               92.92
# 30486            -4175.55
# 30487                -300
# 30488                -350
# 30489               -3650
# 30490             -625.65
# 30491   2226609.260000024
# 30492  238971.87000000052
# 30493                 NaN
# 30494                 NaN
# 30495                 NaN
# 30496     Page 553 of 553
# 30497                 NaN

# %%
dic_company['company_avg']
# Out:
#                                                       0    1   \
# 30499                                                NaN  NaN
# 30500                                                NaN  NaN
# 30501                                                NaN  NaN
# 30502                                                NaN  NaN
# 30503                                                NaN  NaN
# 30504                                                NaN  NaN
# 30505                                                NaN  NaN
# 30506                                                NaN  NaN
# 30507                                                NaN  NaN
# 30508                                                NaN  NaN
# 30509                                                NaN  NaN
# 30510                                                NaN  NaN
# 30511                                                NaN  NaN
# 30512                                                NaN  NaN
# 30513                                                NaN  NaN
# 30514                                                NaN  NaN
# 30515                                                NaN  NaN
# 30516                                                NaN  NaN
# 30517                                                NaN  NaN
# 30518                                                NaN  NaN
# 30519                                                NaN  NaN
# 30520                                                NaN  NaN
# 30521                                                NaN  NaN
# 30522                                                NaN  NaN
# 30523                                                NaN  NaN
# 30524                                                NaN  NaN
# 30525                                                NaN  NaN
# 30526                                                NaN  NaN
# 30527                                                NaN  NaN
# 30528                                                NaN  NaN
# 30529                                                NaN  NaN
# 30530                                                NaN  NaN
# 30531                                                NaN  NaN
# 30532                                                NaN  NaN
# 30533                                                NaN  NaN
# 30534                                                NaN  NaN
# 30535                                                NaN  NaN
# 30536                                                NaN  NaN
# 30537                                                NaN  NaN
# 30538                                                NaN  NaN
# 30539                                                NaN  NaN
# 30540                                                NaN  NaN
# 30541                                                NaN  NaN
# 30542                                                NaN  NaN
# 30543                                                NaN  NaN
# 30544                                                NaN  NaN
# 30545                                                NaN  NaN
# 30546                                                NaN  NaN
# 30547                                                NaN  NaN
# 30548                                                NaN  NaN
# 30549  ACME Payroll (Registered to AMALGAMATED CO. PT...  NaN
#
#                                                 5                     10  \
# 30499                                 Normal Hours    26.447454961395483
# 30500                              Time/Half Hours    0.0982985416070918
# 30501                                   Sick Leave    0.7207034601086646
# 30502                                 Annual Leave    1.8784929939948527
# 30503                           Long Service Leave   0.18272805261652844
# 30504                    Other Leave - Bereavement   0.01372605090077209
# 30505                       Other Leave - Birthday   0.07577923934801258
# 30506                  Other Leave - Compassionate  0.002573634543894767
# 30507                      Other Leave - Jury Duty   0.02973977695167286
# 30508     Other Leave - Leave w/out pay- with accr   0.03009722619388047
# 30509                                         uals                   NaN
# 30510     Other Leave - Paternity Leave- 1 wk paid   0.01143837575064341
# 30511                 Other Leave - Public Holiday    0.4571060909350872
# 30512        Other Leave - Sick Leave - No accrual   0.02030311695739205
# 30513      Other Leave - Unpaid Leave- No accruals   0.21954532456391193
# 30514         Other Leave - Workcover- lve accrued  0.012582213325707749
# 30515                             60% Sun Perm Ldg    1.0275950814984272
# 30516                                        Bonus                     0
# 30517               First Aid - Retail Hourly Rate   0.26780097226193883
# 30518               First Aid- Retail award - wkly                     0
# 30519                                Key Allowance                     0
# 30520                          Leave Loading 17.5%                     0
# 30521                                   Over Award                     0
# 30522                      Public Holiday - worked   0.38182728052616527
# 30523                               Sat Casual Ldg    0.4637546468401487
# 30524                             Sat Perm Loading    0.4956391192450672
# 30525                                  Sun Cas Ldg    0.7264083500142979
# 30526                                   Sunday Ldg   0.41185301687160425
# 30527  ZZZFirst Aid -hourly retail award (don't us                     0
# 30528                                           e)                   NaN
# 30529                  Salary Sacrifice - YSI Life                     0
# 30530            Salary Sacrifice - Carcosan Super                     0
# 30531      Salary Sacrifice - Super Superannuation                     0
# 30532                                Term AL Gross   0.25431798684586787
# 30533                                Term LL Gross                     0
# 30534                               Term LSL Gross   0.27592507863883325
# 30535        ETP - Taxable (Post June 83) Code : O                     0
# 30536                          Gross Taxable Total                     0
# 30537                            Tax (Incl Adjust)                     0
# 30538                               Tax Adjustment                     0
# 30539            Re-imburse expense - Safety Boots                     0
# 30540                           Reimburse expenses                     0
# 30541                  Reimburse expenses- Flu Vax                     0
# 30542                              Account Payment                     0
# 30543                            Jury Duty Subsidy                     0
# 30544           Loan Repayments - Reducing balance                     0
# 30545                       SUPER SUPER VOL CONT $                     0
# 30546                  Uniforms - Reducing Balance                     0
# 30547                                      Net Pay                     0
# 30548                               Superannuation                     0
# 30549                                          NaN                   NaN
#
#                          11
# 30499     601.2990219848743
# 30500    3.0408235630540457
# 30501     17.46101229625396
# 30502     43.63521875893627
# 30503     4.201498427223334
# 30504    0.2871261080926508
# 30505    1.7903717472118963
# 30506   0.10517300543322848
# 30507    0.6397083214183585
# 30508                     0
# 30509                   NaN
# 30510    0.3904460966542751
# 30511     11.16270231627108
# 30512                     0
# 30513                     0
# 30514    0.2843094080640549
# 30515    12.556645696311126
# 30516    1.8444380897912496
# 30517   0.07771232484987135
# 30518    0.6784929939948536
# 30519     2.113811838718902
# 30520     4.988281384043468
# 30521    1.0080068630254504
# 30522     18.05460966542752
# 30523    0.8767143265656273
# 30524     2.703437231913074
# 30525     10.33418072633687
# 30526     7.148830426079477
# 30527    0.3359336574206464
# 30528                   NaN
# 30529   -2.4449528167000287
# 30530   -0.6720045753503002
# 30531   -1.2939662567915355
# 30532     6.045967972547898
# 30533    0.5529482413497283
# 30534     5.851312553617387
# 30535    2.0329968544466683
# 30536     757.0908092651042
# 30537   -118.14812696597083
# 30538   -0.4844152130397484
# 30539  0.057191878753217046
# 30540    0.2959622533600229
# 30541  0.026571346868744638
# 30542   -1.1940377466399772
# 30543  -0.08578781812982557
# 30544  -0.10008578781812982
# 30545    -1.043751787246211
# 30546   -0.1789104947097512
# 30547     636.7198341435585
# 30548     68.33625107234788
# 30549                   NaN

# %% [markdown]
# To make sure the last employee total details are correct, let's have a quick look.

# %%
dic_emp_total['048LOWEP']
# Out:
#                                                       0    1   \
# 30425                                     Employee Total  NaN
# 30426                                                NaN  NaN
# 30427                                                NaN  NaN
# 30428                                                NaN  NaN
# 30429                                                NaN  NaN
# 30430                                                NaN  NaN
# 30431                                                NaN  NaN
# 30432                                                NaN  NaN
# 30433                                                NaN  NaN
# 30434                                                NaN  NaN
# 30435                                                NaN  NaN
# 30436                                                NaN  NaN
# 30437  ACME Payroll (Registered to AMALGAMATED CO. PT...  NaN
# 30438                                                NaN  NaN
# 30439                                                NaN  NaN
# 30440                         Employee Previous Earnings  NaN
# 30441                                    Payroll Company  NaN
#
#                                              5       10                 11
# 30425                                       NaN     NaN                NaN
# 30426                              Normal Hours  2032.5  69378.87999999998
# 30427                                Sick Leave      24             819.24
# 30428                              Annual Leave   199.5             6809.9
# 30429  Other Leave - Paternity Leave- 1 wk paid      40            1365.39
# 30430              Other Leave - Public Holiday      24             819.24
# 30431                                     Bonus       0                500
# 30432                             Term AL Gross  173.71            5929.56
# 30433                       Gross Taxable Total       0  85622.20999999998
# 30434                         Tax (Incl Adjust)       0             -20513
# 30435                                   Net Pay       0  65109.20999999998
# 30436                            Superannuation       0  7393.470000000001
# 30437                                       NaN     NaN                NaN
# 30438                Employee Previous Earnings     NaN                NaN
# 30439               AMALGAMATED WIDGETS PTY LTD     NaN                NaN
# 30440                                       NaN     NaN    Page 552 of 553
# 30441                                       NaN     NaN                NaN

# %% [markdown]
# **THE 5TH AND 6TH STEPS APPLIED AS FOLLOWS:**
# 5. Removed unnecessary rows.
# 6. Removed unnecessary columns.

# %% [markdown]
# Let's keep only salary description value along with pay end dates, hours and amount in employee salary details dataframe.
#
# **Rows to remove in employee salary details dataframe:** Rows with following text strings<br>
# * Employee Previous Earnings
# * Payroll Company
# * For Pay End Periods between 1/07/1982 and 25/06/1985
# * Period End Date
# * Employee Previous Earnings
# * AMALGAMATED WIDGETS PTY LTD
#
# Also, we remove if all values in row are NaN.
#
# Although we remove some rows, we should be aware of some values in it for the future. So that, let's keep it here.<br>
#
# Periods interval: **For Pay End Periods between 1/07/1982 and 25/06/1985**

# %%
# removing rows in df_emp_salary

for emp_id, index in list_index_by_emp:
  df_emp_salary = dic_emp_salary[emp_id]

  # remove rows included specific strings
  df_emp_salary.drop(df_emp_salary[df_emp_salary.iloc[:,0] == 'Employee Previous Earnings'].index, inplace = True)
  df_emp_salary.drop(df_emp_salary[df_emp_salary.iloc[:,0] == 'Payroll Company'].index, inplace = True)
  df_emp_salary.drop(df_emp_salary[df_emp_salary.iloc[:,0] == 'For Pay End Periods between 1/07/1982 and 25/06/1985'].index, inplace = True)
  df_emp_salary.drop(df_emp_salary[df_emp_salary.iloc[:,0] == 'Period End Date'].index, inplace = True)
  df_emp_salary.drop(df_emp_salary[df_emp_salary.iloc[:,0] == emp_id].index, inplace = True)

  df_emp_salary.drop(df_emp_salary[df_emp_salary.iloc[:,2] == 'Employee Previous Earnings'].index, inplace = True)
  df_emp_salary.drop(df_emp_salary[df_emp_salary.iloc[:,2] == 'AMALGAMATED WIDGETS PTY LTD'].index, inplace = True)

  # remove rows if all value NaN
  df_emp_salary.dropna(how='all', axis=0, inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %% [markdown]
# Let's check if unnecessary rows are removed in employee salary dataframe for the employee with ID of "002MORIC".

# %%
dic_emp_salary['002MORIC']
# Out:
#              0              1                    5     10                 11
# 215  1985/04/16  1W01 - Weekly                  NaN   NaN                NaN
# 216         NaN            NaN         Normal Hours    46            1003.22
# 217         NaN            NaN  Gross Taxable Total     0            1003.22
# 218         NaN            NaN    Tax (Incl Adjust)     0                -85
# 219         NaN            NaN              Net Pay     0             918.22
# 220         NaN            NaN       Superannuation     0  95.30000000000001
# 221  1985/04/23  1W01 - Weekly                  NaN   NaN                NaN
# 222         NaN            NaN         Normal Hours  19.5             425.27
# 223         NaN            NaN  Gross Taxable Total     0             425.27
# 224         NaN            NaN    Tax (Incl Adjust)     0                -14
# 225         NaN            NaN              Net Pay     0             411.27
# 226         NaN            NaN       Superannuation     0               40.4
# 227  1985/04/30  1W01 - Weekly                  NaN   NaN                NaN
# 228         NaN            NaN         Normal Hours    30             654.27
# 229         NaN            NaN       Sat Casual Ldg   8.5              14.83
# 230         NaN            NaN  Gross Taxable Total     0              669.1
# 231         NaN            NaN    Tax (Incl Adjust)     0                -73
# 232         NaN            NaN              Net Pay     0              596.1
# 233         NaN            NaN       Superannuation     0              63.56
# 234  1985/05/07  1W01 - Weekly                  NaN   NaN                NaN
# 235         NaN            NaN         Normal Hours     4              87.24
# 236         NaN            NaN  Gross Taxable Total     0              87.24
# 237         NaN            NaN    Tax (Incl Adjust)     0                 -0
# 238         NaN            NaN              Net Pay     0              87.24

# %% [markdown]
# Let's keep only salary total description values along with hours and amount in employee totals dataframe.
#
# **Rows to remove in employee total dataframe:** Rows with following text strings<br>
# * Employee Total
# * ACME Payroll (Registered to AMALGAMATED CO. PTY. LTD.)

# %%
# removing rows in df_emp_total

for emp_id, index in list_index_by_emp:
  df_emp_total = dic_emp_total[emp_id]

  df_emp_total.drop(df_emp_total[df_emp_total.iloc[:,0] == 'Employee Total'].index, inplace = True)
  df_emp_total.drop(df_emp_total[df_emp_total.iloc[:,0] == 'ACME Payroll (Registered to AMALGAMATED CO. PTY. LTD.)'].index, inplace = True)

  # remove rows if all value NaN
  df_emp_total.dropna(how='all', axis=0, inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %% [markdown]
# Let's check if unnecessary rows are removed in employee total dataframe for the employee with ID of "002MORIC".

# %%
dic_emp_total['002MORIC']
# Out:
#       0    1                    5     10                  11
# 240  NaN  NaN         Normal Hours  99.5                2170
# 241  NaN  NaN       Sat Casual Ldg   8.5               14.83
# 242  NaN  NaN  Gross Taxable Total     0             2184.83
# 243  NaN  NaN    Tax (Incl Adjust)     0                -172
# 244  NaN  NaN              Net Pay     0  2012.8300000000002
# 245  NaN  NaN       Superannuation     0  199.26000000000002

# %% [markdown]
# Let's keep only company total and company average description values along with hours and amount in company total and company average dataframes.
#
# **Rows to remove in company total and company average dataframes:** Rows with following text strings<br>
# * ACME Payroll (Registered to AMALGAMATED CO. PTY. LTD.)
# * Employee Previous Earnings
# * Payroll Company
# * AMALGAMATED WIDGETS PTY LTD

# %%
# removing rows in df_company_total and df_company_avg

df_company_total = dic_company['company_total']
df_company_avg = dic_company['company_avg']

# remove rows included specific strings in df_company_total
df_company_total.drop(df_company_total[df_company_total.iloc[:,0] == 'ACME Payroll (Registered to AMALGAMATED CO. PTY. LTD.)'].index, inplace = True)
df_company_total.drop(df_company_total[df_company_total.iloc[:,0] == 'Employee Previous Earnings'].index, inplace = True)
df_company_total.drop(df_company_total[df_company_total.iloc[:,0] == 'Payroll Company'].index, inplace = True)

df_company_total.drop(df_company_total[df_company_total.iloc[:,2] == 'Employee Previous Earnings'].index, inplace = True)
df_company_total.drop(df_company_total[df_company_total.iloc[:,2] == 'AMALGAMATED WIDGETS PTY LTD'].index, inplace = True)

# remove rows if all value NaN in df_company_total
df_company_total.dropna(how='all', axis=0, inplace = True)


# remove rows included specific strings in df_company_avg
df_company_avg.drop(df_company_avg[df_company_avg.iloc[:,0] == 'ACME Payroll (Registered to AMALGAMATED CO. PTY. LTD.)'].index, inplace = True)
df_company_avg.drop(df_company_avg[df_company_avg.iloc[:,0] == 'Employee Previous Earnings'].index, inplace = True)
df_company_avg.drop(df_company_avg[df_company_avg.iloc[:,0] == 'Payroll Company'].index, inplace = True)

df_company_avg.drop(df_company_avg[df_company_avg.iloc[:,2] == 'Employee Previous Earnings'].index, inplace = True)
df_company_avg.drop(df_company_avg[df_company_avg.iloc[:,2] == 'AMALGAMATED WIDGETS PTY LTD'].index, inplace = True)

# remove rows if all value NaN in df_company_avg
df_company_avg.dropna(how='all', axis=0, inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %% [markdown]
# Let's check company total and company average dataframes to make sure all unnecessary rows are removed.

# %%
dic_company['company_total']
# Out:
#         0    1                                            5   \
# 30443  NaN  NaN                                 Normal Hours
# 30444  NaN  NaN                              Time/Half Hours
# 30445  NaN  NaN                                   Sick Leave
# 30446  NaN  NaN                                 Annual Leave
# 30447  NaN  NaN                           Long Service Leave
# 30448  NaN  NaN                    Other Leave - Bereavement
# 30449  NaN  NaN                       Other Leave - Birthday
# 30450  NaN  NaN                  Other Leave - Compassionate
# 30451  NaN  NaN                      Other Leave - Jury Duty
# 30452  NaN  NaN     Other Leave - Leave w/out pay- with accr
# 30453  NaN  NaN                                         uals
# 30454  NaN  NaN     Other Leave - Paternity Leave- 1 wk paid
# 30455  NaN  NaN                 Other Leave - Public Holiday
# 30456  NaN  NaN        Other Leave - Sick Leave - No accrual
# 30457  NaN  NaN      Other Leave - Unpaid Leave- No accruals
# 30458  NaN  NaN         Other Leave - Workcover- lve accrued
# 30459  NaN  NaN                             60% Sun Perm Ldg
# 30460  NaN  NaN                                        Bonus
# 30461  NaN  NaN               First Aid - Retail Hourly Rate
# 30462  NaN  NaN               First Aid- Retail award - wkly
# 30463  NaN  NaN                                Key Allowance
# 30464  NaN  NaN                          Leave Loading 17.5%
# 30465  NaN  NaN                                   Over Award
# 30466  NaN  NaN                      Public Holiday - worked
# 30467  NaN  NaN                               Sat Casual Ldg
# 30468  NaN  NaN                             Sat Perm Loading
# 30469  NaN  NaN                                  Sun Cas Ldg
# 30470  NaN  NaN                                   Sunday Ldg
# 30471  NaN  NaN  ZZZFirst Aid -hourly retail award (don't us
# 30472  NaN  NaN                                           e)
# 30473  NaN  NaN                  Salary Sacrifice - YSI Life
# 30474  NaN  NaN            Salary Sacrifice - Carcosan Super
# 30475  NaN  NaN      Salary Sacrifice - Super Superannuation
# 30476  NaN  NaN                                Term AL Gross
# 30477  NaN  NaN                                Term LL Gross
# 30478  NaN  NaN                               Term LSL Gross
# 30479  NaN  NaN        ETP - Taxable (Post June 83) Code : O
# 30480  NaN  NaN                          Gross Taxable Total
# 30481  NaN  NaN                            Tax (Incl Adjust)
# 30482  NaN  NaN                               Tax Adjustment
# 30483  NaN  NaN            Re-imburse expense - Safety Boots
# 30484  NaN  NaN                           Reimburse expenses
# 30485  NaN  NaN                  Reimburse expenses- Flu Vax
# 30486  NaN  NaN                              Account Payment
# 30487  NaN  NaN                            Jury Duty Subsidy
# 30488  NaN  NaN           Loan Repayments - Reducing balance
# 30489  NaN  NaN                       SUPER SUPER VOL CONT $
# 30490  NaN  NaN                  Uniforms - Reducing Balance
# 30491  NaN  NaN                                      Net Pay
# 30492  NaN  NaN                               Superannuation
#
#                       10                  11
# 30443           92486.75  2102742.6800000034
# 30444             343.75  10633.759999999998
# 30445             2520.3   61061.16000000009
# 30446            6569.09  152592.36000000013
# 30447                639            14692.64
# 30448                 48  1004.0799999999999
# 30449                265   6260.930000000001
# 30450                  9              367.79
# 30451                104             2237.06
# 30452             105.25                   0
# 30453                NaN                 NaN
# 30454                 40             1365.39
# 30455             1598.5  39035.969999999965
# 30456                 71                   0
# 30457             767.75                   0
# 30458                 44              994.23
# 30459             3593.5  43910.590000000004
# 30460                  0                6450
# 30461              936.5   271.7600000000001
# 30462                  0  2372.6900000000032
# 30463                  0                7392
# 30464                  0  17444.020000000008
# 30465                  0                3525
# 30466            1335.25   63136.97000000004
# 30467            1621.75  3065.8699999999985
# 30468            1733.25    9453.92000000002
# 30469            2540.25  36138.630000000034
# 30470            1440.25   24999.45999999993
# 30471                  0  1174.7600000000004
# 30472                NaN                 NaN
# 30473                  0               -8550
# 30474                  0               -2350
# 30475                  0               -4525
# 30476             889.35            21142.75
# 30477                  0  1933.6599999999999
# 30478  964.9099999999999            20462.04
# 30479                  0   7109.389999999999
# 30480                  0  2647546.5600000694
# 30481                  0             -413164
# 30482                  0               -1694
# 30483                  0                 200
# 30484                  0             1034.98
# 30485                  0               92.92
# 30486                  0            -4175.55
# 30487                  0                -300
# 30488                  0                -350
# 30489                  0               -3650
# 30490                  0             -625.65
# 30491                  0   2226609.260000024
# 30492                  0  238971.87000000052

# %%
dic_company['company_avg']
# Out:
#         0    1                                            5   \
# 30499  NaN  NaN                                 Normal Hours
# 30500  NaN  NaN                              Time/Half Hours
# 30501  NaN  NaN                                   Sick Leave
# 30502  NaN  NaN                                 Annual Leave
# 30503  NaN  NaN                           Long Service Leave
# 30504  NaN  NaN                    Other Leave - Bereavement
# 30505  NaN  NaN                       Other Leave - Birthday
# 30506  NaN  NaN                  Other Leave - Compassionate
# 30507  NaN  NaN                      Other Leave - Jury Duty
# 30508  NaN  NaN     Other Leave - Leave w/out pay- with accr
# 30509  NaN  NaN                                         uals
# 30510  NaN  NaN     Other Leave - Paternity Leave- 1 wk paid
# 30511  NaN  NaN                 Other Leave - Public Holiday
# 30512  NaN  NaN        Other Leave - Sick Leave - No accrual
# 30513  NaN  NaN      Other Leave - Unpaid Leave- No accruals
# 30514  NaN  NaN         Other Leave - Workcover- lve accrued
# 30515  NaN  NaN                             60% Sun Perm Ldg
# 30516  NaN  NaN                                        Bonus
# 30517  NaN  NaN               First Aid - Retail Hourly Rate
# 30518  NaN  NaN               First Aid- Retail award - wkly
# 30519  NaN  NaN                                Key Allowance
# 30520  NaN  NaN                          Leave Loading 17.5%
# 30521  NaN  NaN                                   Over Award
# 30522  NaN  NaN                      Public Holiday - worked
# 30523  NaN  NaN                               Sat Casual Ldg
# 30524  NaN  NaN                             Sat Perm Loading
# 30525  NaN  NaN                                  Sun Cas Ldg
# 30526  NaN  NaN                                   Sunday Ldg
# 30527  NaN  NaN  ZZZFirst Aid -hourly retail award (don't us
# 30528  NaN  NaN                                           e)
# 30529  NaN  NaN                  Salary Sacrifice - YSI Life
# 30530  NaN  NaN            Salary Sacrifice - Carcosan Super
# 30531  NaN  NaN      Salary Sacrifice - Super Superannuation
# 30532  NaN  NaN                                Term AL Gross
# 30533  NaN  NaN                                Term LL Gross
# 30534  NaN  NaN                               Term LSL Gross
# 30535  NaN  NaN        ETP - Taxable (Post June 83) Code : O
# 30536  NaN  NaN                          Gross Taxable Total
# 30537  NaN  NaN                            Tax (Incl Adjust)
# 30538  NaN  NaN                               Tax Adjustment
# 30539  NaN  NaN            Re-imburse expense - Safety Boots
# 30540  NaN  NaN                           Reimburse expenses
# 30541  NaN  NaN                  Reimburse expenses- Flu Vax
# 30542  NaN  NaN                              Account Payment
# 30543  NaN  NaN                            Jury Duty Subsidy
# 30544  NaN  NaN           Loan Repayments - Reducing balance
# 30545  NaN  NaN                       SUPER SUPER VOL CONT $
# 30546  NaN  NaN                  Uniforms - Reducing Balance
# 30547  NaN  NaN                                      Net Pay
# 30548  NaN  NaN                               Superannuation
#
#                          10                    11
# 30499    26.447454961395483     601.2990219848743
# 30500    0.0982985416070918    3.0408235630540457
# 30501    0.7207034601086646     17.46101229625396
# 30502    1.8784929939948527     43.63521875893627
# 30503   0.18272805261652844     4.201498427223334
# 30504   0.01372605090077209    0.2871261080926508
# 30505   0.07577923934801258    1.7903717472118963
# 30506  0.002573634543894767   0.10517300543322848
# 30507   0.02973977695167286    0.6397083214183585
# 30508   0.03009722619388047                     0
# 30509                   NaN                   NaN
# 30510   0.01143837575064341    0.3904460966542751
# 30511    0.4571060909350872     11.16270231627108
# 30512   0.02030311695739205                     0
# 30513   0.21954532456391193                     0
# 30514  0.012582213325707749    0.2843094080640549
# 30515    1.0275950814984272    12.556645696311126
# 30516                     0    1.8444380897912496
# 30517   0.26780097226193883   0.07771232484987135
# 30518                     0    0.6784929939948536
# 30519                     0     2.113811838718902
# 30520                     0     4.988281384043468
# 30521                     0    1.0080068630254504
# 30522   0.38182728052616527     18.05460966542752
# 30523    0.4637546468401487    0.8767143265656273
# 30524    0.4956391192450672     2.703437231913074
# 30525    0.7264083500142979     10.33418072633687
# 30526   0.41185301687160425     7.148830426079477
# 30527                     0    0.3359336574206464
# 30528                   NaN                   NaN
# 30529                     0   -2.4449528167000287
# 30530                     0   -0.6720045753503002
# 30531                     0   -1.2939662567915355
# 30532   0.25431798684586787     6.045967972547898
# 30533                     0    0.5529482413497283
# 30534   0.27592507863883325     5.851312553617387
# 30535                     0    2.0329968544466683
# 30536                     0     757.0908092651042
# 30537                     0   -118.14812696597083
# 30538                     0   -0.4844152130397484
# 30539                     0  0.057191878753217046
# 30540                     0    0.2959622533600229
# 30541                     0  0.026571346868744638
# 30542                     0   -1.1940377466399772
# 30543                     0  -0.08578781812982557
# 30544                     0  -0.10008578781812982
# 30545                     0    -1.043751787246211
# 30546                     0   -0.1789104947097512
# 30547                     0     636.7198341435585
# 30548                     0     68.33625107234788

# %% [markdown]
# Let's remove unnecessary columns in all dataframes. <br>
#
# *Employee salary details dataframe*<br>
#
#
# **Columns to remove:** <br>
# Column 1 - Payment frequency with only one unique value of **1W01 - Weekly**.

# %%
for key in dic_emp_salary:
  dic_emp_salary[key] = dic_emp_salary[key].drop(dic_emp_salary[key].columns[[1]], axis=1)

dic_emp_salary['002MORIC']
# Out:
#              0                    5     10                 11
# 215  1985/04/16                  NaN   NaN                NaN
# 216         NaN         Normal Hours    46            1003.22
# 217         NaN  Gross Taxable Total     0            1003.22
# 218         NaN    Tax (Incl Adjust)     0                -85
# 219         NaN              Net Pay     0             918.22
# 220         NaN       Superannuation     0  95.30000000000001
# 221  1985/04/23                  NaN   NaN                NaN
# 222         NaN         Normal Hours  19.5             425.27
# 223         NaN  Gross Taxable Total     0             425.27
# 224         NaN    Tax (Incl Adjust)     0                -14
# 225         NaN              Net Pay     0             411.27
# 226         NaN       Superannuation     0               40.4
# 227  1985/04/30                  NaN   NaN                NaN
# 228         NaN         Normal Hours    30             654.27
# 229         NaN       Sat Casual Ldg   8.5              14.83
# 230         NaN  Gross Taxable Total     0              669.1
# 231         NaN    Tax (Incl Adjust)     0                -73
# 232         NaN              Net Pay     0              596.1
# 233         NaN       Superannuation     0              63.56
# 234  1985/05/07                  NaN   NaN                NaN
# 235         NaN         Normal Hours     4              87.24
# 236         NaN  Gross Taxable Total     0              87.24
# 237         NaN    Tax (Incl Adjust)     0                 -0
# 238         NaN              Net Pay     0              87.24

# %% [markdown]
# *Employee total dataframe*<br>
#
#
# **Columns to remove:** <br>
# Column 0 - Empty <br>
# Column 1 - Empty

# %%
for key in dic_emp_total:
  dic_emp_total[key] = dic_emp_total[key].drop(dic_emp_total[key].columns[[0,1]], axis=1)

dic_emp_total['002MORIC']
# Out:
#                       5     10                  11
# 240         Normal Hours  99.5                2170
# 241       Sat Casual Ldg   8.5               14.83
# 242  Gross Taxable Total     0             2184.83
# 243    Tax (Incl Adjust)     0                -172
# 244              Net Pay     0  2012.8300000000002
# 245       Superannuation     0  199.26000000000002

# %% [markdown]
# *Company total and company average dataframes*<br>
#
#
# **Columns to remove:** <br>
# Column 0 - Empty <br>
# Column 1 - Empty

# %%
#remove columns by indexing
dic_company['company_total'] = dic_company['company_total'].drop(dic_company['company_total'].columns[[0,1]], axis=1)
dic_company['company_total']
# Out:
#                                                 5                  10  \
# 30443                                 Normal Hours           92486.75
# 30444                              Time/Half Hours             343.75
# 30445                                   Sick Leave             2520.3
# 30446                                 Annual Leave            6569.09
# 30447                           Long Service Leave                639
# 30448                    Other Leave - Bereavement                 48
# 30449                       Other Leave - Birthday                265
# 30450                  Other Leave - Compassionate                  9
# 30451                      Other Leave - Jury Duty                104
# 30452     Other Leave - Leave w/out pay- with accr             105.25
# 30453                                         uals                NaN
# 30454     Other Leave - Paternity Leave- 1 wk paid                 40
# 30455                 Other Leave - Public Holiday             1598.5
# 30456        Other Leave - Sick Leave - No accrual                 71
# 30457      Other Leave - Unpaid Leave- No accruals             767.75
# 30458         Other Leave - Workcover- lve accrued                 44
# 30459                             60% Sun Perm Ldg             3593.5
# 30460                                        Bonus                  0
# 30461               First Aid - Retail Hourly Rate              936.5
# 30462               First Aid- Retail award - wkly                  0
# 30463                                Key Allowance                  0
# 30464                          Leave Loading 17.5%                  0
# 30465                                   Over Award                  0
# 30466                      Public Holiday - worked            1335.25
# 30467                               Sat Casual Ldg            1621.75
# 30468                             Sat Perm Loading            1733.25
# 30469                                  Sun Cas Ldg            2540.25
# 30470                                   Sunday Ldg            1440.25
# 30471  ZZZFirst Aid -hourly retail award (don't us                  0
# 30472                                           e)                NaN
# 30473                  Salary Sacrifice - YSI Life                  0
# 30474            Salary Sacrifice - Carcosan Super                  0
# 30475      Salary Sacrifice - Super Superannuation                  0
# 30476                                Term AL Gross             889.35
# 30477                                Term LL Gross                  0
# 30478                               Term LSL Gross  964.9099999999999
# 30479        ETP - Taxable (Post June 83) Code : O                  0
# 30480                          Gross Taxable Total                  0
# 30481                            Tax (Incl Adjust)                  0
# 30482                               Tax Adjustment                  0
# 30483            Re-imburse expense - Safety Boots                  0
# 30484                           Reimburse expenses                  0
# 30485                  Reimburse expenses- Flu Vax                  0
# 30486                              Account Payment                  0
# 30487                            Jury Duty Subsidy                  0
# 30488           Loan Repayments - Reducing balance                  0
# 30489                       SUPER SUPER VOL CONT $                  0
# 30490                  Uniforms - Reducing Balance                  0
# 30491                                      Net Pay                  0
# 30492                               Superannuation                  0
#
#                        11
# 30443  2102742.6800000034
# 30444  10633.759999999998
# 30445   61061.16000000009
# 30446  152592.36000000013
# 30447            14692.64
# 30448  1004.0799999999999
# 30449   6260.930000000001
# 30450              367.79
# 30451             2237.06
# 30452                   0
# 30453                 NaN
# 30454             1365.39
# 30455  39035.969999999965
# 30456                   0
# 30457                   0
# 30458              994.23
# 30459  43910.590000000004
# 30460                6450
# 30461   271.7600000000001
# 30462  2372.6900000000032
# 30463                7392
# 30464  17444.020000000008
# 30465                3525
# 30466   63136.97000000004
# 30467  3065.8699999999985
# 30468    9453.92000000002
# 30469  36138.630000000034
# 30470   24999.45999999993
# 30471  1174.7600000000004
# 30472                 NaN
# 30473               -8550
# 30474               -2350
# 30475               -4525
# 30476            21142.75
# 30477  1933.6599999999999
# 30478            20462.04
# 30479   7109.389999999999
# 30480  2647546.5600000694
# 30481             -413164
# 30482               -1694
# 30483                 200
# 30484             1034.98
# 30485               92.92
# 30486            -4175.55
# 30487                -300
# 30488                -350
# 30489               -3650
# 30490             -625.65
# 30491   2226609.260000024
# 30492  238971.87000000052

# %%
dic_company['company_avg'] = dic_company['company_avg'].drop(dic_company['company_avg'].columns[[0,1]], axis=1)
dic_company['company_avg']
# Out:
#                                                 5                     10  \
# 30499                                 Normal Hours    26.447454961395483
# 30500                              Time/Half Hours    0.0982985416070918
# 30501                                   Sick Leave    0.7207034601086646
# 30502                                 Annual Leave    1.8784929939948527
# 30503                           Long Service Leave   0.18272805261652844
# 30504                    Other Leave - Bereavement   0.01372605090077209
# 30505                       Other Leave - Birthday   0.07577923934801258
# 30506                  Other Leave - Compassionate  0.002573634543894767
# 30507                      Other Leave - Jury Duty   0.02973977695167286
# 30508     Other Leave - Leave w/out pay- with accr   0.03009722619388047
# 30509                                         uals                   NaN
# 30510     Other Leave - Paternity Leave- 1 wk paid   0.01143837575064341
# 30511                 Other Leave - Public Holiday    0.4571060909350872
# 30512        Other Leave - Sick Leave - No accrual   0.02030311695739205
# 30513      Other Leave - Unpaid Leave- No accruals   0.21954532456391193
# 30514         Other Leave - Workcover- lve accrued  0.012582213325707749
# 30515                             60% Sun Perm Ldg    1.0275950814984272
# 30516                                        Bonus                     0
# 30517               First Aid - Retail Hourly Rate   0.26780097226193883
# 30518               First Aid- Retail award - wkly                     0
# 30519                                Key Allowance                     0
# 30520                          Leave Loading 17.5%                     0
# 30521                                   Over Award                     0
# 30522                      Public Holiday - worked   0.38182728052616527
# 30523                               Sat Casual Ldg    0.4637546468401487
# 30524                             Sat Perm Loading    0.4956391192450672
# 30525                                  Sun Cas Ldg    0.7264083500142979
# 30526                                   Sunday Ldg   0.41185301687160425
# 30527  ZZZFirst Aid -hourly retail award (don't us                     0
# 30528                                           e)                   NaN
# 30529                  Salary Sacrifice - YSI Life                     0
# 30530            Salary Sacrifice - Carcosan Super                     0
# 30531      Salary Sacrifice - Super Superannuation                     0
# 30532                                Term AL Gross   0.25431798684586787
# 30533                                Term LL Gross                     0
# 30534                               Term LSL Gross   0.27592507863883325
# 30535        ETP - Taxable (Post June 83) Code : O                     0
# 30536                          Gross Taxable Total                     0
# 30537                            Tax (Incl Adjust)                     0
# 30538                               Tax Adjustment                     0
# 30539            Re-imburse expense - Safety Boots                     0
# 30540                           Reimburse expenses                     0
# 30541                  Reimburse expenses- Flu Vax                     0
# 30542                              Account Payment                     0
# 30543                            Jury Duty Subsidy                     0
# 30544           Loan Repayments - Reducing balance                     0
# 30545                       SUPER SUPER VOL CONT $                     0
# 30546                  Uniforms - Reducing Balance                     0
# 30547                                      Net Pay                     0
# 30548                               Superannuation                     0
#
#                          11
# 30499     601.2990219848743
# 30500    3.0408235630540457
# 30501     17.46101229625396
# 30502     43.63521875893627
# 30503     4.201498427223334
# 30504    0.2871261080926508
# 30505    1.7903717472118963
# 30506   0.10517300543322848
# 30507    0.6397083214183585
# 30508                     0
# 30509                   NaN
# 30510    0.3904460966542751
# 30511     11.16270231627108
# 30512                     0
# 30513                     0
# 30514    0.2843094080640549
# 30515    12.556645696311126
# 30516    1.8444380897912496
# 30517   0.07771232484987135
# 30518    0.6784929939948536
# 30519     2.113811838718902
# 30520     4.988281384043468
# 30521    1.0080068630254504
# 30522     18.05460966542752
# 30523    0.8767143265656273
# 30524     2.703437231913074
# 30525     10.33418072633687
# 30526     7.148830426079477
# 30527    0.3359336574206464
# 30528                   NaN
# 30529   -2.4449528167000287
# 30530   -0.6720045753503002
# 30531   -1.2939662567915355
# 30532     6.045967972547898
# 30533    0.5529482413497283
# 30534     5.851312553617387
# 30535    2.0329968544466683
# 30536     757.0908092651042
# 30537   -118.14812696597083
# 30538   -0.4844152130397484
# 30539  0.057191878753217046
# 30540    0.2959622533600229
# 30541  0.026571346868744638
# 30542   -1.1940377466399772
# 30543  -0.08578781812982557
# 30544  -0.10008578781812982
# 30545    -1.043751787246211
# 30546   -0.1789104947097512
# 30547     636.7198341435585
# 30548     68.33625107234788

# %% [markdown]
# **THE 7TH STEP APPLIED AS FOLLOWS**
# 7. Filled empty dates in emp_salary_details dataframe using ffill() function to make next step (reshaping dataframe) easier.

# %%
for key in dic_emp_salary:
  df_emp_salary = dic_emp_salary[key]
  dic_emp_salary[key][dic_emp_salary[key].columns[0]] = df_emp_salary[df_emp_salary.columns[0]].ffill()

# %%
dic_emp_salary['001POWED']
# Out:
#              0                    5    10      11
# 8    1982/12/06                  NaN  NaN     NaN
# 9    1982/12/06         Normal Hours   23  351.87
# 10   1982/12/06  Gross Taxable Total    0  351.87
# 11   1982/12/06    Tax (Incl Adjust)    0      -0
# 12   1982/12/06              Net Pay    0  351.87
# ..          ...                  ...  ...     ...
# 191  1983/05/30         Normal Hours   25  446.21
# 192  1983/05/30  Gross Taxable Total    0  446.21
# 193  1983/05/30    Tax (Incl Adjust)    0     -21
# 194  1983/05/30              Net Pay    0  425.21
# 195  1983/05/30       Superannuation    0   42.39
#
# [164 rows x 4 columns]

# %%
dic_emp_salary['002MORIC']
# Out:
#              0                    5     10                 11
# 215  1985/04/16                  NaN   NaN                NaN
# 216  1985/04/16         Normal Hours    46            1003.22
# 217  1985/04/16  Gross Taxable Total     0            1003.22
# 218  1985/04/16    Tax (Incl Adjust)     0                -85
# 219  1985/04/16              Net Pay     0             918.22
# 220  1985/04/16       Superannuation     0  95.30000000000001
# 221  1985/04/23                  NaN   NaN                NaN
# 222  1985/04/23         Normal Hours  19.5             425.27
# 223  1985/04/23  Gross Taxable Total     0             425.27
# 224  1985/04/23    Tax (Incl Adjust)     0                -14
# 225  1985/04/23              Net Pay     0             411.27
# 226  1985/04/23       Superannuation     0               40.4
# 227  1985/04/30                  NaN   NaN                NaN
# 228  1985/04/30         Normal Hours    30             654.27
# 229  1985/04/30       Sat Casual Ldg   8.5              14.83
# 230  1985/04/30  Gross Taxable Total     0              669.1
# 231  1985/04/30    Tax (Incl Adjust)     0                -73
# 232  1985/04/30              Net Pay     0              596.1
# 233  1985/04/30       Superannuation     0              63.56
# 234  1985/05/07                  NaN   NaN                NaN
# 235  1985/05/07         Normal Hours     4              87.24
# 236  1985/05/07  Gross Taxable Total     0              87.24
# 237  1985/05/07    Tax (Incl Adjust)     0                 -0
# 238  1985/05/07              Net Pay     0              87.24

# %% [markdown]
# **THE 8TH STEP APPLIED AS FOLLOWS**
# 8. Reshaped dataframes using unstack() function to make dataframe with a one header.

# %% [markdown]
# *Employee salary detail dataframe*

# %%
col_names = ['pay_end_date', 'description', 'hours', 'amount']
for key in dic_emp_salary:
  # assign columns name
  dic_emp_salary[key].columns = col_names

  # TODO: check without dropna!
  dic_emp_salary[key] = dic_emp_salary[key].dropna()

  # set multi index
  dic_emp_salary[key] = dic_emp_salary[key].set_index(['pay_end_date', 'description'])

  # unstack dataframe - inner most level (in our case description)
  dic_emp_salary[key]  = dic_emp_salary[key].unstack()
  # flatten index into "hours_Net Pay", "amount_Net Pay" etc
  dic_emp_salary[key].columns = dic_emp_salary[key].columns.to_flat_index().str.join('_')

  # flatten the index of all levels
  dic_emp_salary[key].reset_index(inplace=True)

  # insert 2 new columns to save employee ids and names
  dic_emp_salary[key].insert(0, "id", key)
  dic_emp_salary[key].insert(1, "name", dic_emp_names[key])

# %%
print("The 1st employee salary dataframe shape: ", dic_emp_salary['001POWED'].shape)
dic_emp_salary['001POWED']
# Out:
# The 1st employee salary dataframe shape:  (26, 21)
#           id             name pay_end_date hours_Gross Taxable Total  \
# 0   001POWED  Dominick Powers   1982/12/06                         0
# 1   001POWED  Dominick Powers   1982/12/13                         0
# 2   001POWED  Dominick Powers   1982/12/20                         0
# 3   001POWED  Dominick Powers   1982/12/27                         0
# 4   001POWED  Dominick Powers   1983/01/03                         0
# 5   001POWED  Dominick Powers   1983/01/10                         0
# 6   001POWED  Dominick Powers   1983/01/17                         0
# 7   001POWED  Dominick Powers   1983/01/24                         0
# 8   001POWED  Dominick Powers   1983/01/31                         0
# 9   001POWED  Dominick Powers   1983/02/07                         0
# 10  001POWED  Dominick Powers   1983/02/14                         0
# 11  001POWED  Dominick Powers   1983/02/21                         0
# 12  001POWED  Dominick Powers   1983/02/28                         0
# 13  001POWED  Dominick Powers   1983/03/07                         0
# 14  001POWED  Dominick Powers   1983/03/14                         0
# 15  001POWED  Dominick Powers   1983/03/21                         0
# 16  001POWED  Dominick Powers   1983/03/28                         0
# 17  001POWED  Dominick Powers   1983/04/04                         0
# 18  001POWED  Dominick Powers   1983/04/11                         0
# 19  001POWED  Dominick Powers   1983/04/18                         0
# 20  001POWED  Dominick Powers   1983/04/25                         0
# 21  001POWED  Dominick Powers   1983/05/02                         0
# 22  001POWED  Dominick Powers   1983/05/09                         0
# 23  001POWED  Dominick Powers   1983/05/16                         0
# 24  001POWED  Dominick Powers   1983/05/23                         0
# 25  001POWED  Dominick Powers   1983/05/30                         0
#
#    hours_Net Pay hours_Normal Hours hours_Public Holiday - worked  \
# 0              0                 23                           NaN
# 1              0                 46                           NaN
# 2              0               37.5                           NaN
# 3              0                 30                            15
# 4              0               37.5                           NaN
# 5              0                 32                           NaN
# 6              0                 31                           NaN
# 7              0                 37                           NaN
# 8              0               33.5                           NaN
# 9              0               35.5                           NaN
# 10             0              35.25                           NaN
# 11             0               34.5                           NaN
# 12             0              35.25                           NaN
# 13             0               35.5                           NaN
# 14             0               35.5                           NaN
# 15             0               35.5                           NaN
# 16             0                 32                           NaN
# 17             0              33.25                           NaN
# 18             0               41.5                           NaN
# 19             0               16.5                           8.5
# 20             0              41.75                           NaN
# 21             0                 25                           NaN
# 22             0                 34                           NaN
# 23             0                 34                           NaN
# 24             0               14.5                           NaN
# 25             0                 25                           NaN
#
#    hours_Reimburse expenses hours_Superannuation hours_Tax (Incl Adjust)  ...  \
# 0                       NaN                  NaN                       0  ...
# 1                       NaN                    0                       0  ...
# 2                       NaN                    0                       0  ...
# 3                       NaN                    0                       0  ...
# 4                       NaN                    0                       0  ...
# 5                       NaN                    0                       0  ...
# 6                       NaN                    0                       0  ...
# 7                       NaN                    0                       0  ...
# 8                       NaN                    0                       0  ...
# 9                         0                    0                       0  ...
# 10                      NaN                    0                       0  ...
# 11                      NaN                    0                       0  ...
# 12                      NaN                    0                       0  ...
# 13                      NaN                    0                       0  ...
# 14                      NaN                    0                       0  ...
# 15                      NaN                    0                       0  ...
# 16                      NaN                    0                       0  ...
# 17                      NaN                    0                       0  ...
# 18                      NaN                    0                       0  ...
# 19                      NaN                    0                       0  ...
# 20                      NaN                    0                       0  ...
# 21                      NaN                  NaN                       0  ...
# 22                      NaN                    0                       0  ...
# 23                      NaN                    0                       0  ...
# 24                      NaN                    0                       0  ...
# 25                      NaN                    0                       0  ...
#
#    hours_Uniforms - Reducing Balance amount_Gross Taxable Total  \
# 0                                NaN                     351.87
# 1                                NaN                     703.74
# 2                                NaN                      573.7
# 3                                NaN                    1032.66
# 4                                NaN                      573.7
# 5                                NaN          615.7700000000001
# 6                                NaN                     474.26
# 7                                NaN                     566.05
# 8                                NaN                     512.51
# 9                                NaN                      543.1
# 10                               NaN                     539.28
# 11                               NaN                     527.81
# 12                               NaN                     539.28
# 13                               NaN                      543.1
# 14                               NaN                      543.1
# 15                                 0                      543.1
# 16                                 0          529.0799999999999
# 17                                 0                     593.47
# 18                               NaN                     740.71
# 19                               NaN                     673.78
# 20                               NaN                     745.17
# 21                               NaN                     446.21
# 22                               NaN                     606.85
# 23                               NaN                     606.85
# 24                               NaN                      258.8
# 25                               NaN                     446.21
#
#         amount_Net Pay amount_Normal Hours amount_Public Holiday - worked  \
# 0               351.87              351.87                            NaN
# 1               623.74              703.74                            NaN
# 2                520.7               573.7                            NaN
# 3    838.6600000000001              458.96                          573.7
# 4                520.7               573.7                            NaN
# 5    553.7700000000001  489.56000000000006                            NaN
# 6               445.26              474.26                            NaN
# 7               514.05              566.05                            NaN
# 8               472.51              512.51                            NaN
# 9                546.1               543.1                            NaN
# 10              493.28              539.28                            NaN
# 11  484.80999999999995              527.81                            NaN
# 12              493.28              539.28                            NaN
# 13               496.1               543.1                            NaN
# 14               496.1               543.1                            NaN
# 15               485.1               543.1                            NaN
# 16   474.0799999999999   529.0799999999999                            NaN
# 17              525.47              593.47                            NaN
# 18              648.71              740.71                            NaN
# 19              599.78               294.5                         379.28
# 20              651.17              745.17                            NaN
# 21              425.21              446.21                            NaN
# 22              546.85              606.85                            NaN
# 23              546.85              606.85                            NaN
# 24               258.8               258.8                            NaN
# 25              425.21              446.21                            NaN
#
#    amount_Reimburse expenses amount_Superannuation amount_Tax (Incl Adjust)  \
# 0                        NaN                   NaN                       -0
# 1                        NaN                 66.86                      -80
# 2                        NaN                  54.5                      -53
# 3                        NaN                  98.1                     -194
# 4                        NaN                  54.5                      -53
# 5                        NaN                 46.51                      -62
# 6                        NaN                 45.05                      -29
# 7                        NaN                 53.77                      -52
# 8                        NaN                 48.69                      -40
# 9                         50                 51.59                      -47
# 10                       NaN                 51.23                      -46
# 11                       NaN                 50.14                      -43
# 12                       NaN                 51.23                      -46
# 13                       NaN                 51.59                      -47
# 14                       NaN                 51.59                      -47
# 15                       NaN                 51.59                      -47
# 16                       NaN                 50.26                      -44
# 17                       NaN                 56.38                      -57
# 18                       NaN                 70.37                      -92
# 19                       NaN                 64.01                      -74
# 20                       NaN                 70.79                      -94
# 21                       NaN                   NaN                      -21
# 22                       NaN                100.04                      -60
# 23                       NaN                 57.65                      -60
# 24                       NaN                 24.59                       -0
# 25                       NaN                 42.39                      -21
#
#    amount_Time/Half Hours amount_Uniforms - Reducing Balance
# 0                     NaN                                NaN
# 1                     NaN                                NaN
# 2                     NaN                                NaN
# 3                     NaN                                NaN
# 4                     NaN                                NaN
# 5                  126.21                                NaN
# 6                     NaN                                NaN
# 7                     NaN                                NaN
# 8                     NaN                                NaN
# 9                     NaN                                NaN
# 10                    NaN                                NaN
# 11                    NaN                                NaN
# 12                    NaN                                NaN
# 13                    NaN                                NaN
# 14                    NaN                                NaN
# 15                    NaN                                -11
# 16                    NaN                                -11
# 17                    NaN                                -11
# 18                    NaN                                NaN
# 19                    NaN                                NaN
# 20                    NaN                                NaN
# 21                    NaN                                NaN
# 22                    NaN                                NaN
# 23                    NaN                                NaN
# 24                    NaN                                NaN
# 25                    NaN                                NaN
#
# [26 rows x 21 columns]

# %%
print("The 2nd employee salary dataframe shape: ", dic_emp_salary['002MORIC'].shape)
dic_emp_salary['002MORIC']
# Out:
# The 2nd employee salary dataframe shape:  (4, 15)
#          id           name pay_end_date hours_Gross Taxable Total  \
# 0  002MORIC  Crystal Morin   1985/04/16                         0
# 1  002MORIC  Crystal Morin   1985/04/23                         0
# 2  002MORIC  Crystal Morin   1985/04/30                         0
# 3  002MORIC  Crystal Morin   1985/05/07                         0
#
#   hours_Net Pay hours_Normal Hours hours_Sat Casual Ldg hours_Superannuation  \
# 0             0                 46                  NaN                    0
# 1             0               19.5                  NaN                    0
# 2             0                 30                  8.5                    0
# 3             0                  4                  NaN                  NaN
#
#   hours_Tax (Incl Adjust) amount_Gross Taxable Total amount_Net Pay  \
# 0                       0                    1003.22         918.22
# 1                       0                     425.27         411.27
# 2                       0                      669.1          596.1
# 3                       0                      87.24          87.24
#
#   amount_Normal Hours amount_Sat Casual Ldg amount_Superannuation  \
# 0             1003.22                   NaN     95.30000000000001
# 1              425.27                   NaN                  40.4
# 2              654.27                 14.83                 63.56
# 3               87.24                   NaN                   NaN
#
#   amount_Tax (Incl Adjust)
# 0                      -85
# 1                      -14
# 2                      -73
# 3                       -0

# %% [markdown]
# *Employee total dataframe*

# %%
col_names = ['description', 'hours', 'amount']
for key in dic_emp_total:
  dic_emp_total[key].columns = col_names
  dic_emp_total[key] = dic_emp_total[key].dropna()
  dic_emp_total[key] = dic_emp_total[key].set_index(['description'])

  dic_emp_total[key]  = dic_emp_total[key].unstack().to_frame().transpose()

  dic_emp_total[key].columns = dic_emp_total[key].columns.to_flat_index().str.join('_')

# %%
print("The 1st employee total dataframe shape: ", dic_emp_total['001POWED'].shape)
dic_emp_total['001POWED']
# Out:
# The 1st employee total dataframe shape:  (1, 18)
#   hours_Normal Hours hours_Time/Half Hours hours_Public Holiday - worked  \
# 0                852                   5.5                          23.5
#
#   hours_Gross Taxable Total hours_Tax (Incl Adjust) hours_Reimburse expenses  \
# 0                         0                       0                        0
#
#   hours_Uniforms - Reducing Balance hours_Net Pay hours_Superannuation  \
# 0                                 0             0                    0
#
#   amount_Normal Hours amount_Time/Half Hours amount_Public Holiday - worked  \
# 0            13750.97                 126.21                         952.98
#
#   amount_Gross Taxable Total amount_Tax (Incl Adjust)  \
# 0                   14830.16                    -1409
#
#   amount_Reimburse expenses amount_Uniforms - Reducing Balance amount_Net Pay  \
# 0                        50                                -33       13438.16
#
#   amount_Superannuation
# 0               1363.42

# %%
print("The last employee total dataframe shape: ", dic_emp_total['048LOWEP'].shape)
dic_emp_total['048LOWEP']
# Out:
# The last employee total dataframe shape:  (1, 22)
#   hours_Normal Hours hours_Sick Leave hours_Annual Leave  \
# 0             2032.5               24              199.5
#
#   hours_Other Leave - Paternity Leave- 1 wk paid  \
# 0                                             40
#
#   hours_Other Leave - Public Holiday hours_Bonus hours_Term AL Gross  \
# 0                                 24           0              173.71
#
#   hours_Gross Taxable Total hours_Tax (Incl Adjust) hours_Net Pay  ...  \
# 0                         0                       0             0  ...
#
#   amount_Sick Leave amount_Annual Leave  \
# 0            819.24              6809.9
#
#   amount_Other Leave - Paternity Leave- 1 wk paid  \
# 0                                         1365.39
#
#   amount_Other Leave - Public Holiday amount_Bonus amount_Term AL Gross  \
# 0                              819.24          500              5929.56
#
#   amount_Gross Taxable Total amount_Tax (Incl Adjust)     amount_Net Pay  \
# 0          85622.20999999998                   -20513  65109.20999999998
#
#   amount_Superannuation
# 0     7393.470000000001
#
# [1 rows x 22 columns]

# %% [markdown]
# *Company total and company average dataframes*

# %%
col_names = ['description', 'hours', 'amount']
for key in dic_company:
  dic_company[key].columns = col_names
  dic_company[key] = dic_company[key].dropna()
  dic_company[key] = dic_company[key].set_index(['description'])

  dic_company[key]  = dic_company[key].unstack().to_frame().transpose()

  dic_company[key].columns = dic_company[key].columns.to_flat_index().str.join('_')

# %%
print("The company total dataframe shape: ", dic_company['company_total'].shape)
dic_company['company_total']
# Out:
# The company total dataframe shape:  (1, 96)
#   hours_Normal Hours hours_Time/Half Hours hours_Sick Leave  \
# 0           92486.75                343.75           2520.3
#
#   hours_Annual Leave hours_Long Service Leave hours_Other Leave - Bereavement  \
# 0            6569.09                      639                              48
#
#   hours_Other Leave - Birthday hours_Other Leave - Compassionate  \
# 0                          265                                 9
#
#   hours_Other Leave - Jury Duty  \
# 0                           104
#
#   hours_Other Leave - Leave w/out pay- with accr  ...  \
# 0                                         105.25  ...
#
#   amount_Re-imburse expense - Safety Boots amount_Reimburse expenses  \
# 0                                      200                   1034.98
#
#   amount_Reimburse expenses- Flu Vax amount_Account Payment  \
# 0                              92.92               -4175.55
#
#   amount_Jury Duty Subsidy amount_Loan Repayments - Reducing balance  \
# 0                     -300                                      -350
#
#   amount_SUPER SUPER VOL CONT $ amount_Uniforms - Reducing Balance  \
# 0                         -3650                            -625.65
#
#       amount_Net Pay amount_Superannuation
# 0  2226609.260000024    238971.87000000052
#
# [1 rows x 96 columns]

# %%
print("The company average dataframe shape: ", dic_company['company_avg'].shape)
dic_company['company_avg']
# Out:
# The company average dataframe shape:  (1, 96)
#    hours_Normal Hours hours_Time/Half Hours    hours_Sick Leave  \
# 0  26.447454961395483    0.0982985416070918  0.7207034601086646
#
#    hours_Annual Leave hours_Long Service Leave  \
# 0  1.8784929939948527      0.18272805261652844
#
#   hours_Other Leave - Bereavement hours_Other Leave - Birthday  \
# 0             0.01372605090077209          0.07577923934801258
#
#   hours_Other Leave - Compassionate hours_Other Leave - Jury Duty  \
# 0              0.002573634543894767           0.02973977695167286
#
#   hours_Other Leave - Leave w/out pay- with accr  ...  \
# 0                            0.03009722619388047  ...
#
#   amount_Re-imburse expense - Safety Boots amount_Reimburse expenses  \
# 0                     0.057191878753217046        0.2959622533600229
#
#   amount_Reimburse expenses- Flu Vax amount_Account Payment  \
# 0               0.026571346868744638    -1.1940377466399772
#
#   amount_Jury Duty Subsidy amount_Loan Repayments - Reducing balance  \
# 0     -0.08578781812982557                      -0.10008578781812982
#
#   amount_SUPER SUPER VOL CONT $ amount_Uniforms - Reducing Balance  \
# 0            -1.043751787246211                -0.1789104947097512
#
#       amount_Net Pay amount_Superannuation
# 0  636.7198341435585     68.33625107234788
#
# [1 rows x 96 columns]

# %% [markdown]
# **THE 9TH AND 10TH STEPS APPLIED AS FOLLOWS**
# 9. Concatenated all dataframes to the one big dataframe.
# 10. Exported resulted dataframe into CSV.

# %%
list_df_all_emp = []
for key in dic_emp_salary:
  list_df_all_emp.append(dic_emp_salary[key])
  list_df_all_emp.append(dic_emp_total[key])

list_df_all_emp.append(dic_company['company_total'])
list_df_all_emp.append(dic_company['company_avg'])

result = pd.concat(list_df_all_emp, ignore_index=True, sort=False)

# %%
print("The result dataframe shape: ", result.shape)
result.head(32)
# Out:
# The result dataframe shape:  (3509, 103)
#           id             name pay_end_date hours_Gross Taxable Total  \
# 0   001POWED  Dominick Powers   1982/12/06                         0
# 1   001POWED  Dominick Powers   1982/12/13                         0
# 2   001POWED  Dominick Powers   1982/12/20                         0
# 3   001POWED  Dominick Powers   1982/12/27                         0
# 4   001POWED  Dominick Powers   1983/01/03                         0
# 5   001POWED  Dominick Powers   1983/01/10                         0
# 6   001POWED  Dominick Powers   1983/01/17                         0
# 7   001POWED  Dominick Powers   1983/01/24                         0
# 8   001POWED  Dominick Powers   1983/01/31                         0
# 9   001POWED  Dominick Powers   1983/02/07                         0
# 10  001POWED  Dominick Powers   1983/02/14                         0
# 11  001POWED  Dominick Powers   1983/02/21                         0
# 12  001POWED  Dominick Powers   1983/02/28                         0
# 13  001POWED  Dominick Powers   1983/03/07                         0
# 14  001POWED  Dominick Powers   1983/03/14                         0
# 15  001POWED  Dominick Powers   1983/03/21                         0
# 16  001POWED  Dominick Powers   1983/03/28                         0
# 17  001POWED  Dominick Powers   1983/04/04                         0
# 18  001POWED  Dominick Powers   1983/04/11                         0
# 19  001POWED  Dominick Powers   1983/04/18                         0
# 20  001POWED  Dominick Powers   1983/04/25                         0
# 21  001POWED  Dominick Powers   1983/05/02                         0
# 22  001POWED  Dominick Powers   1983/05/09                         0
# 23  001POWED  Dominick Powers   1983/05/16                         0
# 24  001POWED  Dominick Powers   1983/05/23                         0
# 25  001POWED  Dominick Powers   1983/05/30                         0
# 26       NaN              NaN          NaN                         0
# 27  002MORIC    Crystal Morin   1985/04/16                         0
# 28  002MORIC    Crystal Morin   1985/04/23                         0
# 29  002MORIC    Crystal Morin   1985/04/30                         0
# 30  002MORIC    Crystal Morin   1985/05/07                         0
# 31       NaN              NaN          NaN                         0
#
#    hours_Net Pay hours_Normal Hours hours_Public Holiday - worked  \
# 0              0                 23                           NaN
# 1              0                 46                           NaN
# 2              0               37.5                           NaN
# 3              0                 30                            15
# 4              0               37.5                           NaN
# 5              0                 32                           NaN
# 6              0                 31                           NaN
# 7              0                 37                           NaN
# 8              0               33.5                           NaN
# 9              0               35.5                           NaN
# 10             0              35.25                           NaN
# 11             0               34.5                           NaN
# 12             0              35.25                           NaN
# 13             0               35.5                           NaN
# 14             0               35.5                           NaN
# 15             0               35.5                           NaN
# 16             0                 32                           NaN
# 17             0              33.25                           NaN
# 18             0               41.5                           NaN
# 19             0               16.5                           8.5
# 20             0              41.75                           NaN
# 21             0                 25                           NaN
# 22             0                 34                           NaN
# 23             0                 34                           NaN
# 24             0               14.5                           NaN
# 25             0                 25                           NaN
# 26             0                852                          23.5
# 27             0                 46                           NaN
# 28             0               19.5                           NaN
# 29             0                 30                           NaN
# 30             0                  4                           NaN
# 31             0               99.5                           NaN
#
#    hours_Reimburse expenses hours_Superannuation hours_Tax (Incl Adjust)  ...  \
# 0                       NaN                  NaN                       0  ...
# 1                       NaN                    0                       0  ...
# 2                       NaN                    0                       0  ...
# 3                       NaN                    0                       0  ...
# 4                       NaN                    0                       0  ...
# 5                       NaN                    0                       0  ...
# 6                       NaN                    0                       0  ...
# 7                       NaN                    0                       0  ...
# 8                       NaN                    0                       0  ...
# 9                         0                    0                       0  ...
# 10                      NaN                    0                       0  ...
# 11                      NaN                    0                       0  ...
# 12                      NaN                    0                       0  ...
# 13                      NaN                    0                       0  ...
# 14                      NaN                    0                       0  ...
# 15                      NaN                    0                       0  ...
# 16                      NaN                    0                       0  ...
# 17                      NaN                    0                       0  ...
# 18                      NaN                    0                       0  ...
# 19                      NaN                    0                       0  ...
# 20                      NaN                    0                       0  ...
# 21                      NaN                  NaN                       0  ...
# 22                      NaN                    0                       0  ...
# 23                      NaN                    0                       0  ...
# 24                      NaN                    0                       0  ...
# 25                      NaN                    0                       0  ...
# 26                        0                    0                       0  ...
# 27                      NaN                    0                       0  ...
# 28                      NaN                    0                       0  ...
# 29                      NaN                    0                       0  ...
# 30                      NaN                  NaN                       0  ...
# 31                      NaN                    0                       0  ...
#
#    hours_Salary Sacrifice - Super Superannuation amount_Bonus  \
# 0                                            NaN          NaN
# 1                                            NaN          NaN
# 2                                            NaN          NaN
# 3                                            NaN          NaN
# 4                                            NaN          NaN
# 5                                            NaN          NaN
# 6                                            NaN          NaN
# 7                                            NaN          NaN
# 8                                            NaN          NaN
# 9                                            NaN          NaN
# 10                                           NaN          NaN
# 11                                           NaN          NaN
# 12                                           NaN          NaN
# 13                                           NaN          NaN
# 14                                           NaN          NaN
# 15                                           NaN          NaN
# 16                                           NaN          NaN
# 17                                           NaN          NaN
# 18                                           NaN          NaN
# 19                                           NaN          NaN
# 20                                           NaN          NaN
# 21                                           NaN          NaN
# 22                                           NaN          NaN
# 23                                           NaN          NaN
# 24                                           NaN          NaN
# 25                                           NaN          NaN
# 26                                           NaN          NaN
# 27                                           NaN          NaN
# 28                                           NaN          NaN
# 29                                           NaN          NaN
# 30                                           NaN          NaN
# 31                                           NaN          NaN
#
#    amount_Other Leave - Workcover- lve accrued  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29                                         NaN
# 30                                         NaN
# 31                                         NaN
#
#    amount_Salary Sacrifice - Super Superannuation  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# 30                                            NaN
# 31                                            NaN
#
#    hours_Salary Sacrifice - Carcosan Super  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
# 29                                     NaN
# 30                                     NaN
# 31                                     NaN
#
#    amount_Salary Sacrifice - Carcosan Super hours_Other Leave - Compassionate  \
# 0                                       NaN                               NaN
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                       NaN                               NaN
# 4                                       NaN                               NaN
# 5                                       NaN                               NaN
# 6                                       NaN                               NaN
# 7                                       NaN                               NaN
# 8                                       NaN                               NaN
# 9                                       NaN                               NaN
# 10                                      NaN                               NaN
# 11                                      NaN                               NaN
# 12                                      NaN                               NaN
# 13                                      NaN                               NaN
# 14                                      NaN                               NaN
# 15                                      NaN                               NaN
# 16                                      NaN                               NaN
# 17                                      NaN                               NaN
# 18                                      NaN                               NaN
# 19                                      NaN                               NaN
# 20                                      NaN                               NaN
# 21                                      NaN                               NaN
# 22                                      NaN                               NaN
# 23                                      NaN                               NaN
# 24                                      NaN                               NaN
# 25                                      NaN                               NaN
# 26                                      NaN                               NaN
# 27                                      NaN                               NaN
# 28                                      NaN                               NaN
# 29                                      NaN                               NaN
# 30                                      NaN                               NaN
# 31                                      NaN                               NaN
#
#    amount_Other Leave - Compassionate  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# 10                                NaN
# 11                                NaN
# 12                                NaN
# 13                                NaN
# 14                                NaN
# 15                                NaN
# 16                                NaN
# 17                                NaN
# 18                                NaN
# 19                                NaN
# 20                                NaN
# 21                                NaN
# 22                                NaN
# 23                                NaN
# 24                                NaN
# 25                                NaN
# 26                                NaN
# 27                                NaN
# 28                                NaN
# 29                                NaN
# 30                                NaN
# 31                                NaN
#
#    hours_Other Leave - Paternity Leave- 1 wk paid  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# 30                                            NaN
# 31                                            NaN
#
#    amount_Other Leave - Paternity Leave- 1 wk paid
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
# 20                                             NaN
# 21                                             NaN
# 22                                             NaN
# 23                                             NaN
# 24                                             NaN
# 25                                             NaN
# 26                                             NaN
# 27                                             NaN
# 28                                             NaN
# 29                                             NaN
# 30                                             NaN
# 31                                             NaN
#
# [32 rows x 103 columns]

# %%
# export result dataframe to CSV file
result.to_csv('/content/result.csv')

# %% [markdown]
# ### FURTHER IMPROVEMENTS
#
#
# *   Find out all missing values
# *   Find out all duplicated values and remove duplications
# *   Remove column names auto sorting
# *   Rename column names
# *   Remove columns if values are all 0, NaN or None
# *   Make easier visualisation where client can filter data by name, date or certain column names.
# *   Provide report by each employee if it is necessary.
# *   Code review to make it efficient.

# %% [markdown]
# Here is the end of my task. Thank you for your time go through all the work and I hope the team see me to discuss about the approach.
